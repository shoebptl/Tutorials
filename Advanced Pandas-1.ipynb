# %%
import pandas as pd

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# where method

# %%
df["quality_updated"] = df["quality"].where(df["alcohol"] < 10, 0)
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
# Mask method: reverse of where method

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=';')

# %%
df["quality_updated"] = df["quality"].mask(df["alcohol"] >= 10, 0)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  quality_updated
# 0      9.4        5                5
# ...

# %%
# Numpy where method
#numpy.where intakes a condition as the first parameter, but then has two parameters, a value if true parameter and a value if false parameter.

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=';')

# %%
import numpy as np
df["quality_updated"] = np.where(df["alcohol"] >= 10, 0, df["quality"])
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df["sugar_level"] = np.where(df["residual sugar"] > 2, "Sweet", "Dry")
df[["residual sugar", "sugar_level"]]
# Out:
#       residual sugar sugar_level
# 0                1.9         Dry
# 1                2.6       Sweet
# 2                2.3       Sweet
# 3                1.9         Dry
# 4                1.9         Dry
# ...              ...         ...
# 1594             2.0         Dry
# 1595             2.2       Sweet
# 1596             2.3       Sweet
# 1597             2.0         Dry
# 1598             3.6       Sweet
#
# [1599 rows x 2 columns]

# %%
sugar_cutoff = 4
alcohol_cutoff = 10
mask = ((df["residual sugar"] < sugar_cutoff) & (df["alcohol"] < alcohol_cutoff))
penalty = 0.75
df["quality_updated"] = np.where(mask, df["quality"], df["quality"] * penalty)
df[["residual sugar", "alcohol", "quality", "quality_updated"]].sort_values("quality_updated", ascending=False).head(20)
# Out:
#       residual sugar  alcohol  quality  quality_updated
# 440              2.2      9.8        8              8.0
# 943              2.3      9.7        7              7.0
# 1088             1.5      9.9        7              7.0
# 37               2.1      9.7        7              7.0
# 339              2.3      9.8        7              7.0
# 583              1.9      9.9        7              7.0
# 1089             1.5      9.9        7              7.0
# 62               1.9      9.5        7              7.0
# 244              2.2      9.2        7              7.0
# 243              2.2      9.2        7              7.0
# 281              3.5      9.9        7              7.0
# 8                2.0      9.5        7              7.0
# 308              2.4      9.5        6              6.0
# 307              2.4      9.5        6              6.0
# 305              2.5      9.3        6              6.0
# 309              1.7      9.5        6              6.0
# ...

# %%
# Advanced Booleans

# %%
import pandas as pd

df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df[df["quality"].isin([3, 8])]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267             7.9             0.350         0.46            3.60      0.078
# 278            10.3             0.320         0.45            6.40      0.073
# 390             5.6             0.850         0.05            1.40      0.045
# 440            12.6             0.310         0.72            2.20      0.072
# 455            11.3             0.620         0.67            5.20      0.086
# 459            11.6             0.580         0.66            2.20      0.074
# 481             9.4             0.300         0.56            2.80      0.080
# 495            10.7             0.350         0.53            2.60      0.070
# 498            10.7             0.350         0.53            2.60      0.070
# 517            10.4             0.610         0.49            2.10      0.200
# 588             5.0             0.420         0.24            2.00      0.060
# ...

# %%
df[df["fixed acidity"].between(11.0, 11.4)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2             0.280         0.56            1.90      0.075
# 209            11.0             0.300         0.58            2.10      0.054
# 252            11.1             0.350         0.48            3.10      0.090
# 280            11.4             0.260         0.44            3.60      0.071
# 291            11.0             0.200         0.48            2.00      0.343
# 301            11.1             0.180         0.48            1.50      0.068
# 378            11.4             0.625         0.66            6.20      0.088
# 403            11.4             0.600         0.49            2.70      0.085
# 437            11.1             0.450         0.73            3.20      0.066
# 455            11.3             0.620         0.67            5.20      0.086
# 462            11.0             0.260         0.68            2.55      0.085
# ...

# %%
import random
import string
["".join(random.choices(string.ascii_lowercase, k=20)) for i in range(len(df))][:4]
# Out:
# ['lhwyworodjfmzradwrcp',
#  'vvfqvajdxhqiqvzlmfjn',
#  'ptrbwuhwxnohxuwsqukk',
#  'nbcgaktlivtytuwyfmiu']

# %%
import random
import string

df["random strings"] = ["".join(random.choices(string.ascii_lowercase, k=20)) for i in range(len(df))]

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality        random strings
# 0      9.4        5  calibangfitazerapsdu
# ...

# %%
df[df["random strings"].str.contains("gg")]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 13              7.8             0.610         0.29            1.60      0.114
# 37              8.1             0.380         0.28            2.10      0.066
# 66              7.5             0.520         0.11            1.50      0.079
# 95              4.7             0.600         0.17            2.30      0.058
# 101             7.8             0.500         0.30            1.90      0.075
# 118             8.8             0.550         0.04            2.20      0.119
# 235             7.2             0.630         0.00            1.90      0.097
# 237             7.2             0.645         0.00            1.90      0.097
# 257             6.6             0.695         0.00            2.10      0.075
# 268             6.9             0.540         0.04            3.00      0.077
# 314             7.4             0.360         0.29            2.60      0.087
# ...

# %%
df[df["random strings"].str.count("gg") > 1]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 824            7.1              0.48         0.28             2.8      0.068
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 824                  6.0                  16.0  0.99682  3.24       0.53
#
#      alcohol  quality        random strings
# 824     10.3        5  jtefuicyhcggdwjggbch

# %%
df[df["random strings"].str.find("gg") > 10]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 13              7.8              0.61         0.29            1.60      0.114
# 95              4.7              0.60         0.17            2.30      0.058
# 101             7.8              0.50         0.30            1.90      0.075
# 118             8.8              0.55         0.04            2.20      0.119
# 356            11.5              0.41         0.52            3.00      0.080
# 453            10.4              0.33         0.63            2.80      0.084
# 505            10.2              0.49         0.63            2.90      0.072
# 586            11.1              0.31         0.49            2.70      0.094
# 609             6.3              0.36         0.19            3.20      0.075
# 617            11.5              0.31         0.51            2.20      0.079
# 670             6.9              0.40         0.24            2.50      0.083
# ...

# %%
df[df["random strings"].str.isnumeric() > 1]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality, random strings]
# Index: []

# %%
df[df["random strings"].str.isupper()]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality, random strings]
# Index: []

# %%
from datetime import datetime, date
import random

date_list = list(pd.date_range('2017-01-01 23:34:00', periods=len(df)))
random.shuffle(date_list)

df["random datetimes"] = date_list
df["random dates"] = df["random datetimes"].dt.date

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality        random strings    random datetimes random dates
# ...

# %%
df[["random datetimes", "random dates"]].dtypes
# Out:
# random datetimes    datetime64[ns]
# random dates                object
# dtype: object

# %%
df.at[0, "random datetimes"]
# Out:
# Timestamp('2017-03-31 23:34:00')

# %%
df.at[0, "random dates"]
# Out:
# datetime.date(2017, 3, 31)

# %%
df["random dates"] = pd.to_datetime(df["random dates"])

# %%
df[["random datetimes", "random dates"]].dtypes
# Out:
# random datetimes    datetime64[ns]
# random dates        datetime64[ns]
# dtype: object

# %%
df.at[0, "random dates"]
# Out:
# Timestamp('2017-03-31 00:00:00')

# %%
df[df["random dates"].dt.year == 2021]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 20              8.9             0.220         0.48             1.8      0.077
# 38              5.7             1.130         0.09             1.5      0.172
# 48              6.4             0.400         0.23             1.6      0.066
# ...             ...               ...          ...             ...        ...
# 1518            7.4             0.470         0.46             2.2      0.114
# 1548           11.2             0.400         0.50             2.0      0.099
# 1554            6.6             0.855         0.02             2.4      0.062
# 1583            6.2             0.460         0.29             2.1      0.074
# 1594            6.2             0.600         0.08             2.0      0.090
#
# ...

# %%
df[df["random datetimes"].dt.is_month_end]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 84              6.3             0.300         0.48            1.80      0.069
# 86              8.6             0.490         0.28            1.90      0.110
# 96              6.8             0.775         0.00            3.00      0.102
# 109             8.1             0.785         0.52            2.00      0.122
# 197            11.5             0.300         0.60            2.00      0.067
# 217             8.1             0.725         0.22            2.20      0.072
# 262             8.0             0.520         0.03            1.70      0.070
# 272            10.9             0.370         0.58            4.00      0.071
# 352             7.7             0.665         0.00            2.40      0.090
# 357            10.5             0.420         0.66            2.95      0.116
# ...

# %%
df[df["random datetimes"].between('2020-01-01', '2020-01-10')]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 300             7.5             0.530         0.06             2.6      0.086
# 547            10.6             0.310         0.49             2.5      0.067
# 609             6.3             0.360         0.19             3.2      0.075
# 615             9.6             0.600         0.50             2.3      0.079
# 673             8.2             0.730         0.21             1.7      0.074
# 749             7.3             0.510         0.18             2.1      0.070
# 910             9.3             0.380         0.48             3.8      0.132
# 914             7.3             0.305         0.39             1.2      0.059
# 1092            7.0             0.540         0.09             2.0      0.081
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 300                  20.0                  44.0  0.99650  3.38       0.59
# ...

# %%
df["random booleans"] = [random.random() > 0.5 for i in range(len(df))]
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality        random strings    random datetimes random dates  \
# ...

# %%
[random.random() for i in range(10)]
# Out:
# [0.7679823586357286,
#  0.9607954680902193,
#  0.10617414298455985,
#  0.7686467889639476,
#  0.16998609549406596,
#  0.8365089628505408,
#  0.005516491072021346,
#  0.2635997773334978,
#  0.3909420532420833,
#  0.05832168300458407]

# %%
[random.random() >0.5 for i in range(10)]
# Out:
# [False, True, True, False, True, True, True, True, True, False]

# %%
df[~df["random booleans"]]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# 10              6.7              0.58         0.08             1.8      0.097
# 11              7.5              0.50         0.36             6.1      0.071
# ...             ...               ...          ...             ...        ...
# 1591            5.4              0.74         0.09             1.7      0.089
# 1593            6.8              0.62         0.08             1.9      0.068
# 1594            6.2              0.60         0.08             2.0      0.090
# 1596            6.3              0.51         0.13             2.3      0.076
# 1598            6.0              0.31         0.47             3.6      0.067
#
# ...

# %%
# cleaning data-Pandas workout

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('celebrity_deaths_2016.csv',usecols=['dateofdeath','age'])
df.head()
# Out:
#   dateofdeath age
# 0  2016-01-01  71
# 1  2016-01-01  74
# 2  2016-01-01  79
# 3  2016-01-01  45
# 4  2016-01-01  83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6543 entries, 0 to 6542
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dateofdeath  6543 non-null   object
#  1   age          6516 non-null   object
# dtypes: object(2)
# memory usage: 102.4+ KB

# %%
df['dateofdeath']=pd.to_datetime(df['dateofdeath'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6543 entries, 0 to 6542
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dateofdeath  6543 non-null   datetime64[ns]
#  1   age          6516 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 102.4+ KB

# %%
df['month']=df['dateofdeath'].dt.month

# %%
df.head()
# Out:
#   dateofdeath age  month
# 0  2016-01-01  71      1
# 1  2016-01-01  74      1
# 2  2016-01-01  79      1
# 3  2016-01-01  45      1
# 4  2016-01-01  83      1

# %%
df.set_index('month',inplace=True)

# %%
df.head()
# Out:
#       dateofdeath age
# month
# 1      2016-01-01  71
# 1      2016-01-01  74
# 1      2016-01-01  79
# 1      2016-01-01  45
# 1      2016-01-01  83

# %%
df.sort_index()
# Out:
#       dateofdeath age
# month
# 1      2016-01-01  71
# 1      2016-01-21  47
# 1      2016-01-21  87
# 1      2016-01-21  90
# 1      2016-01-21  73
# ...           ...  ..
# 12     2016-12-10  63
# 12     2016-12-10  20
# 12     2016-12-10  57
# 12     2016-12-10  78
# 12     2016-12-27  84
#
# [6543 rows x 2 columns]

# %%
df.head()
# Out:
#       dateofdeath age
# month
# 1      2016-01-01  71
# 1      2016-01-01  74
# 1      2016-01-01  79
# 1      2016-01-01  45
# 1      2016-01-01  83

# %%
df['age'].isna().sum()
# Out:
# 27

# %%
df['age'].dropna(inplace=True)

# %%
df['age'].isna().sum()
# Out:
# 0

# %%
filt=df['age'].str.isdigit()
filt.loc[filt==False]
# Out:
# month
# 1     False
# 2     False
# 2     False
# 2     False
# 2     False
# 3     False
# 3     False
# 3     False
# 3     False
# 4     False
# 4     False
# 4     False
# 4     False
# 4     False
# 5     False
# 5     False
# 5     False
# 5     False
# 5     False
# 5     False
# 7     False
# 7     False
# 7     False
# 8     False
# 8     False
# 8     False
# 8     False
# 9     False
# 9     False
# 10    False
# 10    False
# 10    False
# 11    False
# 11    False
# 12    False
# Name: age, dtype: bool

# %%
filt.value_counts()
# Out:
# True     6481
# False      35
# Name: age, dtype: int64

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    month dateofdeath age
# 0      1  2016-01-01  71
# 1      1  2016-01-01  74
# 2      1  2016-01-01  79
# 3      1  2016-01-01  45
# 4      1  2016-01-01  83

# %%
filt=df['age'].str.isdigit()
filt.loc[filt==False].index
# Out:
# Int64Index([ 149,  810,  946, 1043, 1224, 1491, 1628, 1718, 1807, 1892, 2014,
#             2057, 2080, 2198, 2408, 2515, 2594, 2595, 2661, 2772, 3664, 3844,
#             3884, 4176, 4327, 4337, 4516, 4642, 4720, 5343, 5369, 5502, 5697,
#             5698, 6339],
#            dtype='int64')

# %%
df.drop(df.index[[ 149,  810,  946, 1043, 1224, 1491, 1628, 1718, 1807, 1892, 2014,
            2057, 2080, 2198, 2408, 2515, 2594, 2595, 2661, 2772, 3664, 3844,
            3884, 4176, 4327, 4337, 4516, 4642, 4720, 5343, 5369, 5502, 5697,
            5698, 6339]],inplace=True)

# %%
df.shape
# Out:
# (6508, 3)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# month          0
# dateofdeath    0
# age            0
# dtype: int64

# %%
df['age'] = df['age'].astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6481 entries, 0 to 6542
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        6481 non-null   int64
#  1   dateofdeath  6481 non-null   datetime64[ns]
#  2   age          6481 non-null   int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 202.5 KB

# %%
df.set_index('month',inplace=True)

# %%
df
# Out:
#       dateofdeath  age
# month
# 1      2016-01-01   71
# 1      2016-01-01   74
# 1      2016-01-01   79
# 1      2016-01-01   45
# 1      2016-01-01   83
# ...           ...  ...
# 12     2016-12-27   74
# 12     2016-12-27   85
# 12     2016-12-27   83
# 12     2016-12-27   23
# 12     2016-12-27   84
#
# [6481 rows x 2 columns]

# %%
df['day']=df['dateofdeath'].dt.day

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    month dateofdeath  age  day
# 0      1  2016-01-01   71    1
# 1      1  2016-01-01   74    1
# 2      1  2016-01-01   79    1
# 3      1  2016-01-01   45    1
# 4      1  2016-01-01   83    1

# %%
df.set_index(['month','day'],inplace=True)

# %%
df.head()
# Out:
#           dateofdeath  age
# month day
# 1     1    2016-01-01   71
#       1    2016-01-01   74
#       1    2016-01-01   79
#       1    2016-01-01   45
#       1    2016-01-01   83

# %%
df.loc[[(2,15),(3,15),(4,15),(5,15),(6,15),(7,15)]]
# Out:
#           dateofdeath  age
# month day
# 2     15   2016-02-15   83
#       15   2016-02-15   58
#       15   2016-02-15   59
#       15   2016-02-15   88
#       15   2016-02-15   57
# ...               ...  ...
# 7     15   2016-07-15   82
#       15   2016-07-15   82
#       15   2016-07-15   83
#       15   2016-07-15   85
#       15   2016-07-15   89
#
# [109 rows x 2 columns]

# %%
df.loc[[(2,15),(3,15),(4,15),(5,15),(6,15),(7,15)]]['age'].mean()
# Out:
# 76.65137614678899

# %%
# Find the average age of celebrities who died during that period

# %%
df.head()
# Out:
#       dateofdeath  age
# month
# 1      2016-01-01   71
# 1      2016-01-01   74
# 1      2016-01-01   79
# 1      2016-01-01   45
# 1      2016-01-01   83

# %%
df['age'].mean()
# Out:
# 77.0192871470452

# %%
df.loc[2:7, 'age'].mean()
# Out:
# 77.18104753254617

# %%
#

# %%
df=pd.read_csv('celebrity_deaths_2016.csv',usecols=['dateofdeath','age','causeofdeath'])
df.head()
# Out:
#   dateofdeath age                causeofdeath
# 0  2016-01-01  71                brain cancer
# 1  2016-01-01  74                      cancer
# 2  2016-01-01  79                      cancer
# 3  2016-01-01  45   complications of a stroke
# 4  2016-01-01  83               heart failure

# %%
df['causeofdeath'].value_counts()[:5]
# Out:
#  cancer               248
#  heart attack         125
#  traffic collision     56
#  lung cancer           51
#  pneumonia             50
# Name: causeofdeath, dtype: int64

# %%
df['causeofdeath']=np.where(df['causeofdeath']==np.nan,'unknown',df['causeofdeath'])

# %%
df['causeofdeath'].value_counts()[:5]
# Out:
#  cancer               248
#  heart attack         125
#  traffic collision     56
#  lung cancer           51
#  pneumonia             50
# Name: causeofdeath, dtype: int64

# %%
df['causeofdeath'].value_counts()[:10]
# Out:
#  cancer               248
#  heart attack         125
#  traffic collision     56
#  lung cancer           51
#  pneumonia             50
#  heart failure         49
#  shot                  42
#  stroke                36
#  pancreatic cancer     35
#  brain cancer          33
# Name: causeofdeath, dtype: int64

# %%
df.head()
# Out:
#   dateofdeath age                causeofdeath
# 0  2016-01-01  71                brain cancer
# 1  2016-01-01  74                      cancer
# 2  2016-01-01  79                      cancer
# 3  2016-01-01  45   complications of a stroke
# 4  2016-01-01  83               heart failure

# %%
# titanic example

# %%
df=pd.read_excel('titanic3.xls')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
s=df.isnull().sum()

# %%
s
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
s.loc[s>0]
# Out:
# age           263
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
s.loc[s>0].index
# Out:
# Index(['age', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'], dtype='object')

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
#

# %%
df=pd.read_csv('celebrity_deaths_2016.csv',usecols=['dateofdeath','age','causeofdeath'])
df.head()
# Out:
#   dateofdeath age                causeofdeath
# 0  2016-01-01  71                brain cancer
# 1  2016-01-01  74                      cancer
# 2  2016-01-01  79                      cancer
# 3  2016-01-01  45   complications of a stroke
# 4  2016-01-01  83               heart failure

# %%
all_good_df=df.dropna()

# %%
# total missing values would be:
df.shape[0]-all_good_df.shape[0]
# Out:
# 5012

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6543 entries, 0 to 6542
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dateofdeath   6543 non-null   object
#  1   age           6516 non-null   object
#  2   causeofdeath  1535 non-null   object
# dtypes: object(3)
# memory usage: 153.5+ KB

# %%
df.shape[0]
# Out:
# 6543

# %%
all_good_df.shape[0]
# Out:
# 1531

# %%
#

# %%
df=pd.read_csv('college.csv',usecols=['instnm','city','stabbr','relaffil','satvrmid','satmtmid','distanceonly','ugds'])

# %%
df.head()
# Out:
#                                 instnm        city stabbr  relaffil  satvrmid  \
# 0             Alabama A & M University      Normal     AL         0     424.0
# 1  University of Alabama at Birmingham  Birmingham     AL         0     570.0
# 2                   Amridge University  Montgomery     AL         1       NaN
# 3  University of Alabama in Huntsville  Huntsville     AL         0     595.0
# 4             Alabama State University  Montgomery     AL         0     425.0
#
#    satmtmid  distanceonly     ugds
# 0     420.0           0.0   4206.0
# 1     565.0           0.0  11383.0
# 2       NaN           1.0    291.0
# 3     590.0           0.0   5451.0
# 4     430.0           0.0   4811.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   instnm        7535 non-null   object
#  1   city          7535 non-null   object
#  2   stabbr        7535 non-null   object
#  3   relaffil      7535 non-null   int64
#  4   satvrmid      1185 non-null   float64
#  5   satmtmid      1196 non-null   float64
#  6   distanceonly  7164 non-null   float64
#  7   ugds          6874 non-null   float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 471.1+ KB

# %%
df.isna().sum()
# Out:
# instnm             0
# city               0
# stabbr             0
# relaffil           0
# satvrmid        6350
# satmtmid        6339
# distanceonly     371
# ugds             661
# dtype: int64

# %%
df_drop_dist_ugds=df.dropna(subset=['distanceonly','ugds'])

# %%
df_drop_dist_ugds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6874 entries, 0 to 7163
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   instnm        6874 non-null   object
#  1   city          6874 non-null   object
#  2   stabbr        6874 non-null   object
#  3   relaffil      6874 non-null   int64
#  4   satvrmid      1185 non-null   float64
#  5   satmtmid      1196 non-null   float64
#  6   distanceonly  6874 non-null   float64
#  7   ugds          6874 non-null   float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 483.3+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   instnm        7535 non-null   object
#  1   city          7535 non-null   object
#  2   stabbr        7535 non-null   object
#  3   relaffil      7535 non-null   int64
#  4   satvrmid      1185 non-null   float64
#  5   satmtmid      1196 non-null   float64
#  6   distanceonly  7164 non-null   float64
#  7   ugds          6874 non-null   float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 471.1+ KB

# %%
df_drop_dist_ugds.isna().sum()
# Out:
# instnm             0
# city               0
# stabbr             0
# relaffil           0
# satvrmid        5689
# satmtmid        5678
# distanceonly       0
# ugds               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   instnm        7535 non-null   object
#  1   city          7535 non-null   object
#  2   stabbr        7535 non-null   object
#  3   relaffil      7535 non-null   int64
#  4   satvrmid      1185 non-null   float64
#  5   satmtmid      1196 non-null   float64
#  6   distanceonly  7164 non-null   float64
#  7   ugds          6874 non-null   float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 471.1+ KB

# %%
df.isna().sum()
# Out:
# instnm             0
# city               0
# stabbr             0
# relaffil           0
# satvrmid        6350
# satmtmid        6339
# distanceonly     371
# ugds             661
# dtype: int64

# %%
df.isna().sum().idxmax()
# Out:
# 'satvrmid'

# %%
# EDA of diabetes dataset

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# How many columns (features) does the data contain?

# %%
df.shape[1]
# Out:
# 9

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# How many rows (features) does the data contain?

# %%
df.shape[0]
# Out:
# 768

# %% [markdown]
# ## Further Inspection

# %% [markdown]
# Do any of the columns in the data contain null (missing) values?

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Note:
#
# 1: minimum is 0 in some columns like Glucose,BP,skin thickness
#
# 2: outliers are insulin(846 very high) and maximum pregnencies is 17 very high

# %% [markdown]
# Note: As you can see, EDA helps inform the data cleaning process by helping catch things that aren’t immediately obvious.

# %%
# Replace the 0 values with np.nan

# %%
df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  763.000000     733.000000     541.000000  394.000000
# mean      3.845052  121.686763      72.405184      29.153420  155.548223
# std       3.369578   30.535641      12.382158      10.476982  118.775855
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      22.000000   76.250000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# ...

# %%
# Next, check for missing (null) values in all of the columns

# %%
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
# Let’s take a closer look at these rows to get a better idea of why some data might be missing.

#Print out all of the rows that contain missing (null) values.

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 5              5    116.0           74.0            NaN      NaN  25.6
# 7             10    115.0            NaN            NaN      NaN  35.3
# ..           ...      ...            ...            ...      ...   ...
# 761            9    170.0           74.0           31.0      NaN  44.0
# 762            9     89.0           62.0            NaN      NaN  22.5
# 764            2    122.0           70.0           27.0      NaN  36.8
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df[df.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# check dtypes of all the columns

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                     float64
# BloodPressure               float64
# SkinThickness               float64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
#or
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   763 non-null    float64
#  2   BloodPressure             733 non-null    float64
#  3   SkinThickness             541 non-null    float64
#  4   Insulin                   394 non-null    float64
#  5   BMI                       757 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df['Outcome'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# Project: Students

# %%
df=pd.read_csv('students.csv')
df.head()
# Out:
#   address  absences     Mjob      Fjob  math_grade
# 0       U         6  at_home   teacher           6
# 1       U         4  at_home     other           6
# 2       U        10  at_home     other          10
# 3       U         2   health  services          15
# 4       U         4    other     other          10

# %%
df.describe(include='all')
# Out:
#        address    absences   Mjob   Fjob  math_grade
# count      395  395.000000    395    395  395.000000
# unique       2         NaN      5      5         NaN
# top          U         NaN  other  other         NaN
# freq       307         NaN    141    217         NaN
# mean       NaN    5.708861    NaN    NaN   10.415190
# std        NaN    8.003096    NaN    NaN    4.581443
# min        NaN    0.000000    NaN    NaN    0.000000
# 25%        NaN    0.000000    NaN    NaN    8.000000
# 50%        NaN    4.000000    NaN    NaN   11.000000
# 75%        NaN    8.000000    NaN    NaN   14.000000
# max        NaN   75.000000    NaN    NaN   20.000000

# %%
df['math_grade'].mean()
# Out:
# 10.415189873417722

# %%
df['math_grade'].median()
# Out:
# 11.0

# %%
df['math_grade'].mode()
# Out:
# 0    10
# dtype: int64

# %%
# range
df['math_grade'].max()-df['math_grade'].min()
# Out:
# 20

# %%
df['math_grade'].std()
# Out:
# 4.5814426109978434

# %% [markdown]
# #The standard deviation is about 4.6, while the average grade is about 10.4. This means that about two thirds(68%) of students are earning a grade between 5.8 (calculated as 10.4 - 4.6) and 15 (calculated as 10.4 + 4.6).

# %%
df['math_grade'].mad()
# Out:
# 3.4289889440794745

# %%
#Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(x='math_grade',data=df)

plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-294-301e01840859> in <module>
# ----> 1 sns.histplot(x='math_grade',data=df)
#       2
#       3 plt.show()
#       4 plt.clf()
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
sns.boxplot(x='math_grade',data=df)
plt.show()
plt.clf()

# %%
df['Mjob'].value_counts()
# Out:
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: Mjob, dtype: int64

# %%
df['Mjob'].value_counts(normalize=True)
# Out:
# other       0.356962
# services    0.260759
# at_home     0.149367
# teacher     0.146835
# health      0.086076
# Name: Mjob, dtype: float64

# %%
sns.countplot(x='Mjob',data=df)
plt.show()

# %%
df['Mjob'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# Congratulations! You’ve begun to explore a dataset by calculating summary statistics and creating some basic data visualizations. There are still a few more columns in this dataset that we haven’t looked at carefully:
#
# address: the location of the student’s home ('U' for urban and 'R' for rural)
#
# absences: the number of times the student was absent during the school year
#
# Fjob: the student’s father’s job industry

# %%
df.head()
# Out:
#   address  absences     Mjob      Fjob  math_grade
# 0       U         6  at_home   teacher           6
# 1       U         4  at_home     other           6
# 2       U        10  at_home     other          10
# 3       U         2   health  services          15
# 4       U         4    other     other          10

# %%
df['address'].value_counts(normalize=True)
# Out:
# U    0.777215
# R    0.222785
# Name: address, dtype: float64

# %%
df['Fjob'].value_counts()
# Out:
# other       217
# services    111
# teacher      29
# at_home      20
# health       18
# Name: Fjob, dtype: int64

# %%
df['absences'].value_counts().sort_index()
# Out:
# 0     115
# 1       3
# 2      65
# 3       8
# 4      53
# 5       5
# 6      31
# 7       7
# 8      22
# 9       3
# 10     17
# 11      3
# 12     12
# 13      3
# 14     12
# 15      3
# 16      7
# 17      1
# 18      5
# 19      1
# 20      4
# 21      1
# 22      3
# 23      1
# 24      1
# 25      1
# 26      1
# 28      1
# 30      1
# 38      1
# 40      1
# 54      1
# 56      1
# 75      1
# Name: absences, dtype: int64

# %%
df.head()
# Out:
#   address  absences     Mjob      Fjob  math_grade
# 0       U         6  at_home   teacher           6
# 1       U         4  at_home     other           6
# 2       U        10  at_home     other          10
# 3       U         2   health  services          15
# 4       U         4    other     other          10

# %%
df[df['address']=='U']['math_grade'].mean()
# Out:
# 10.674267100977199

# %%
df[df['address']=='R']['math_grade'].mean()
# Out:
# 9.511363636363637

# %%
df[df['address']=='U']['math_grade'].median()
# Out:
# 11.0

# %%
df[df['address']=='R']['math_grade'].median()
# Out:
# 10.0

# %%
df.head()
# Out:
#   address  absences     Mjob      Fjob  math_grade
# 0       U         6  at_home   teacher           6
# 1       U         4  at_home     other           6
# 2       U        10  at_home     other          10
# 3       U         2   health  services          15
# 4       U         4    other     other          10

# %%
df[df['Mjob']=='at_home']['math_grade'].mean()
# Out:
# 9.152542372881356

# %%
df[df['Mjob']!='at_home']['math_grade'].mean()
# Out:
# 10.636904761904763

# %%
sns.scatterplot(x='absences',y='math_grade',data=df)

# %%
df.head()
# Out:
#   address  absences     Mjob      Fjob  math_grade
# 0       U         6  at_home   teacher           6
# 1       U         4  at_home     other           6
# 2       U        10  at_home     other          10
# 3       U         2   health  services          15
# 4       U         4    other     other          10

# %%
df[df['Mjob']=='teacher']['math_grade'].mean()
# Out:
# 11.051724137931034

# %%
df['Mjob'].value_counts()
# Out:
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: Mjob, dtype: int64

# %%
df[df['Mjob']!='teacher']['math_grade'].mean()
# Out:
# 10.305637982195845

# %%
df['math_grade'].mean()
# Out:
# 10.415189873417722

# %%
df[df['Fjob']=='teacher']['math_grade'].mean()
# Out:
# 11.96551724137931

# %%
df[df['Fjob']!='teacher']['math_grade'].mean()
# Out:
# 10.292349726775956

# %% [markdown]
# ## ASSOCIATIONS: QUANTITATIVE AND CATEGORICAL VARIABLES

# %%
df=pd.read_csv('students1.csv')
df.head()
# Out:
#   school address  absences     Mjob      Fjob  G3
# 0     GP       U         6  at_home   teacher   6
# 1     GP       U         4  at_home     other   6
# 2     GP       U        10  at_home     other  10
# 3     GP       U         2   health  services  15
# 4     GP       U         4    other     other  10

# %%
df['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
# categorical are school address Mjob Fjob
# quantitative are absences and G3

# %%
scores_urban=df[df['address']=='U']['G3']
scores_rural=df[df['address']=='R']['G3']

# %%
scores_urban.head()
# Out:
# 0     6
# 1     6
# 2    10
# 3    15
# 4    10
# Name: G3, dtype: int64

# %%
scores_rural.head()
# Out:
# 24     8
# 32    16
# 37    15
# 38    11
# 39    13
# Name: G3, dtype: int64

# %%
scores_urban_mean = scores_urban.mean()
scores_rural_mean = scores_rural.mean()

#print mean scores:
print('Mean score - students w/ urban address:')
print(scores_urban_mean)
print('Mean score - students w/ rural address:')
print(scores_rural_mean)
# Out:
# Mean score - students w/ urban address:
# 10.674267100977199
# Mean score - students w/ rural address:
# 9.511363636363637

# %%
#calculate mean difference:
mean_diff = scores_urban_mean-scores_rural_mean
print(mean_diff)
# Out:
# 1.1629034646135619

# %%
#calculate medians for each group:
scores_urban_median = np.median(scores_urban)
scores_rural_median = np.median(scores_rural)

#print median scores
print('Median score - students w/ urban address:')
print(scores_urban_median)
print('Median score - students w/ rural address:')
print(scores_rural_median)
# Out:
# Median score - students w/ urban address:
# 11.0
# Median score - students w/ rural address:
# 10.0

# %%
students = pd.read_csv('students1.csv')

scores_urban = students['G3'][students.address == 'U']
scores_rural = students['G3'][students.address == 'R']

#calculate means for each group:
scores_urban_mean = np.mean(scores_urban)
scores_rural_mean = np.mean(scores_rural)

#print mean scores:
print('Mean score - students w/ urban address:')
print(scores_urban_mean)
print('Mean score - students w/ rural address:')
print(scores_rural_mean)

#calculate mean difference:
mean_diff = scores_urban_mean - scores_rural_mean

#print mean difference
print('Mean difference:')
print(mean_diff)

#calculate medians for each group:
scores_urban_median = np.median(scores_urban)
scores_rural_median = np.median(scores_rural)

#print median scores
print('Median score - students w/ urban address:')
print(scores_urban_median)
print('Median score - students w/ rural address:')
print(scores_rural_median)

#calculate median difference
median_diff = scores_urban_median - scores_rural_median

#print median difference
print('Median difference:')
print(median_diff)
# Out:
# Mean score - students w/ urban address:
# 10.674267100977199
# Mean score - students w/ rural address:
# 9.511363636363637
# Mean difference:
# 1.1629034646135619
# Median score - students w/ urban address:
# 11.0
# Median score - students w/ rural address:
# 10.0
# Median difference:
# 1.0

# %%
sns.boxplot(data = df, x = 'school', y = 'G3')
plt.show()

# %%
sns.boxplot(data = df, x = 'address', y = 'G3')
plt.show()

# %%
scores_GP=students[students['school']=='GP']['G3']
scores_MS=students[students['school']=='MS']['G3']

# %%
plt.hist(scores_GP , color="blue",normed=True, label="GP", alpha=0.5)
plt.hist(scores_MS , color="red", normed=True,label="MS", alpha=0.5)
plt.legend()
plt.show()
# Out:
# C:\Users\soheb\anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\soheb\anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %%
plt.hist(scores_urban , color="blue", label="Urban",normed=True, alpha=0.5)
plt.hist(scores_rural , color="red", label="Rural", normed=True,alpha=0.5)
plt.legend()
plt.show()
# Out:
# C:\Users\soheb\anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\soheb\anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %%
#Exploring Non-Binary Categorical Variables

# %%
sns.boxplot(data = students, x = 'Mjob', y = 'G3')
plt.show()

# %%
sns.boxplot(data = students, x = 'Fjob', y = 'G3')
plt.show()

# %%
# Project titanic

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# To practice the skills learned in this lesson, let’s investigate whether there is an association between the fare that a passenger paid (Fare) and whether or not they survived (Survived, which is equal to 0 if the passenger died and 1 if they survived):

# %%
#1 Calculate the difference in mean fare paid by those who survived and those who died. 
#Which group paid a higher average fare?

# %%
survived_mean=titanic[titanic['Survived']==1]['Fare'].mean()
survived_mean
# Out:
# 48.39540760233917

# %%
dead_mean=titanic[titanic['Survived']==0]['Fare'].mean()
dead_mean
# Out:
# 22.117886885245877

# %%
diff_mean=survived_mean-dead_mean

# %%
diff_mean
# Out:
# 26.277520717093292

# %%
# Answer: The survived mean paid an higher average fare

# %%
#2: Calculate the difference in median fare for those who survived and those who died.

# %%
survived_median=titanic[titanic['Survived']==1]['Fare'].median()
survived_median
# Out:
# 26.0

# %%
dead_median=titanic[titanic['Survived']==0]['Fare'].median()
dead_median
# Out:
# 10.5

# %%
diff_median=survived_median-dead_median
diff_median
# Out:
# 15.5

# %%
#Create side-by-side box plots of fares by survival. Now that you can see the spread of the data, 
#do the mean/median differences seem relatively small or large?

# %%
sns.boxplot(data = titanic, x ='Survived', y = 'Fare')
plt.show()

# %%
#Create overlapping histograms of fares by survival (you’ll have to delete or comment out your box plot code before you try to make a histogram).
#Does this provide any additional information?

# %%
fares_survived=titanic[titanic['Survived']==1]['Fare']
fares_died=titanic[titanic['Survived']==0]['Fare']

# %%
plt.hist(fares_survived , color="blue", label="Survived",normed=True, alpha=0.5)
plt.hist(fares_died , color="red", label="died", normed=True,alpha=0.5)
plt.legend()
plt.show()
# Out:
# C:\Users\soheb\anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\soheb\anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %%
# codeacademy solution:

# %%
titanic = pd.read_csv('titanic.csv')

print(titanic.head())

#separate out fares by survival
fares_died = titanic.Fare[titanic.Survived == 0]
fares_survived = titanic.Fare[titanic.Survived == 1]

#mean difference
mean_fare_died = np.mean(fares_died)
mean_fare_surv = np.mean(fares_survived)
mean_diff = mean_fare_surv-mean_fare_died
print('mean difference: ')
print(mean_diff)

#median difference
med_fare_died = np.median(fares_died)
med_fare_surv = np.median(fares_survived)
med_diff = med_fare_surv-med_fare_died
print("median difference: ")
print(med_diff)

#create subplots (scroll to see plots)
fig = plt.figure(figsize = (10,20))

#create the boxplot:
ax = fig.add_subplot(2,1,1)
ax = sns.boxplot(data = titanic, x = 'Survived', y = 'Fare')

#create the histograms:
ax = fig.add_subplot(2,1,2)
ax = plt.hist(fares_died, color="blue", label="Died", normed=True, alpha=0.5)
ax = plt.hist(fares_survived, color="red", label="Survived", normed=True, alpha=0.5)
ax = plt.legend()
plt.show()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %% [markdown]
# ## ASSOCIATIONS: TWO QUANTITATIVE VARIABLES

# %%
housing = pd.read_csv('housing_sample.csv')

# %% [markdown]
# # Data Dictionary:
# price: monthly rental price in U.S.D.
#
# type: type of housing (eg., 'apartment', 'house', 'condo', etc.)
#
# sqfeet: housing area, in square feet
#
# beds: number of beds
#
# baths: number of baths
#
# lat: latitude
#
# long: longitude

# %%
housing.head(10)
# Out:
#    price       type  sqfeet  beds  baths      lat      long
# 0    615  apartment     364     0    1.0  35.1653 -101.8840
# 1   1346  apartment     816     1    1.0  32.9865  -96.6860
# 2    900  apartment     500     1    1.0  30.2355  -97.7292
# 3    650  apartment     700     1    1.0  26.1923  -98.2657
# 4   1330  apartment    1040     2    2.0  30.6380  -96.2940
# 5    915  apartment     620     1    1.0  29.8754  -97.9404
# 6   1600      house    1578     3    2.0  32.6412  -97.1058
# 7    349  apartment     275     0    1.0  33.5865 -101.8610
# 8    695      house     650     1    1.0  31.5525  -97.1604
# 9    889  apartment     650     1    1.5  29.8754  -97.9404

# %%
housing.dtypes
# Out:
# price       int64
# type       object
# sqfeet      int64
# beds        int64
# baths     float64
# lat       float64
# long      float64
# dtype: object

# %%
plt.scatter(x = housing['price'], y = housing['sqfeet'])
plt.xlabel('Rental Price (USD)')
plt.ylabel('Area (Square Feet)')
plt.show()

# %%
plt.scatter(x = housing['beds'], y = housing['sqfeet'])
plt.xlabel('Sq Feet')
plt.ylabel('No. of Beds')
plt.show()

# %% [markdown]
# ## Exploring Covariance

# %%
cov_mat_price_sqfeet = np.cov(housing.price, housing.sqfeet)
print(cov_mat_price_sqfeet)
# Out:
# [[150471.6135777   65426.51623487]
#  [ 65426.51623487 110668.97801735]]

# %%
# calculate and print covariance matrix:
cov_mat_sqfeet_beds = np.cov(housing.beds, housing.sqfeet)
print(cov_mat_sqfeet_beds)
# Out:
# [[7.24471949e-01 2.28223306e+02]
#  [2.28223306e+02 1.10668978e+05]]

# %%
	variable 1	variable 2
variable 1	variance(variable 1)	covariance
variable 2	covariance	variance(variable 2)

# %%
# find the covariance of sqfeet and beds
cov_sqfeet_beds=cov_mat_sqfeet_beds[1][0]

# %% [markdown]
# ## ASSOCIATIONS: TWO QUANTITATIVE VARIABLES

# %%
from scipy.stats import pearsonr
corr_price_sqfeet, p = pearsonr(housing.price, housing.sqfeet)
print(corr_price_sqfeet)
# Out:
# 0.5070065351127467

# %%
#Generally, a correlation larger than about .3 indicates a linear association.
#A correlation greater than about .6 suggestions a strong linear association.

# %%
from scipy.stats import pearsonr
corr_sqfeet_beds, p = pearsonr(housing.sqfeet, housing.beds)
print(corr_sqfeet_beds)
# Out:
# 0.8060022524416222

# %%
plt.scatter(x = housing['beds'], y = housing['sqfeet'])
plt.xlabel('Sq feet')
plt.ylabel('No. of Beds')
plt.show()

# %%
# Project

# %%
import seaborn as sns

from scipy.stats import pearsonr
np.set_printoptions(suppress=True, precision = 1) 

penguins = pd.read_csv('penguins.csv')

# %%
# Inspect the first few rows of data.

# %%
penguins.head(10)
# Out:
#   species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Adelie            39.1           18.7              181.0       3750.0
# 1  Adelie            39.5           17.4              186.0       3800.0
# 2  Adelie            40.3           18.0              195.0       3250.0
# 3  Adelie            36.7           19.3              193.0       3450.0
# 4  Adelie            39.3           20.6              190.0       3650.0
# 5  Adelie            38.9           17.8              181.0       3625.0
# 6  Adelie            39.2           19.6              195.0       4675.0
# 7  Adelie            41.1           17.6              182.0       3200.0
# 8  Adelie            38.6           21.2              191.0       3800.0
# 9  Adelie            34.6           21.1              198.0       4400.0
#
#       sex
# 0    male
# 1  female
# 2  female
# 3  female
# 4    male
# 5  female
# 6    male
# 7  female
# 8    male
# 9    male

# %%
# Create a scatter plot of flipper length (flipper_length_mm) and body mass (body_mass_g).

# %%
plt.scatter(x = penguins['flipper_length_mm'], y=penguins['body_mass_g'])
plt.xlabel('Flipper Length')
plt.ylabel('Body Mass')
plt.show()

# %%
# Inspect your plot. What is the relationship between these variables?
# Answer: It has positive relationship

# %%
# Calculate the covariance for these two variables.

# %%
cov_mat_flength_bodymass = np.cov(penguins.flipper_length_mm, penguins.body_mass_g)
print(cov_mat_flength_bodymass)
# Out:
# [[   196.4   9852.2]
#  [  9852.2 648372.5]]

# %%
# Calculate the correlation for these two variables. Does this number make sense given the plot you created?

# %%
from scipy.stats import pearsonr
corr_flength_bodymass, p = pearsonr(penguins.flipper_length_mm,penguins.body_mass_g)
print(corr_flength_bodymass)
# Out:
# 0.8729788985653613

# %%
# Answer: very very positive relationship

# %%
#####

# %% [markdown]
# ## ASSOCIATIONS: TWO CATEGORICAL VARIABLES

# %%
npi = pd.read_csv("npi_sample.csv")

# %%
# we’ll explore a sample of data from the Narcissistic Personality Inventory (NPI-40), a personality test with 40 questions about personal preferences and self-view.
#There are two possible responses to each question. 
#The sample we’ll be working with contains responses to the following:

# %%
# influence: yes = I have a natural talent for influencing people; no = I am not good at influencing people.
# blend_in: yes = I prefer to blend in with the crowd; no = I like to be the center of attention.
# special: yes = I think I am a special person; no = I am no better or worse than most people.
# leader: yes = I see myself as a good leader; no = I am not sure if I would make a good leader.
# authority: yes = I like to have authority over other people; no = I don’t mind following orders.

# %%
# As you might guess, responses to some of these questions are associated. For example, if we know whether someone views themself as a good leader, we may also find that they’re more likely to like having authority. 
# In this lesson we’ll learn how to assess whether an association exists between any two of these variables.

# %%
npi.head()
# Out:
#   influence blend_in special leader authority
# 0        no      yes     yes    yes       yes
# 1        no      yes      no     no        no
# 2       yes       no     yes    yes       yes
# 3       yes       no      no    yes       yes
# 4       yes      yes      no    yes        no

# %% [markdown]
# ## Contingency Tables: Frequencies
# Contingency tables, also known as two-way tables or cross-tabulations, are useful for summarizing two variables at the same time. For example, suppose we are interested in understanding whether there is an association between influence (whether a person thinks they have a talent for influencing people) and leader (whether they see themself as a leader). We can use the crosstab function from pandas to create a contingency table:

# %% [markdown]
# ## Association: 1

# %%
influence_leader_freq = pd.crosstab(npi.influence, npi.leader)
print(influence_leader_freq)
# Out:
# leader       no   yes
# influence
# no         3015  1293
# yes        2360  4429

# %% [markdown]
# ## conclusions:
# This table tells us the number of people who gave each possible combination of responses to these two questions. For example, 2360 people said that they do not see themselves as a leader but have a talent for influencing people.
#
# To assess whether there is an association between these two variables, we need to ask whether information about one variable gives us information about the other. In this example, we see that among people who don’t see themselves as a leader (the first column), a larger number (3015) don’t think they have a talent for influencing people. Meanwhile, among people who do see themselves as a leader (the second column), a larger number (4429) do think they have a talent for influencing people.
#
# So, if we know how someone responded to the leadership question, we have some information about how they are likely to respond to the influence question. This suggests that the variables are associated.

# %% [markdown]
# ## Association:2
#
# Do you think there will be an association between special (whether or not a person sees themself as “special”) and authority (whether or not a person likes to have authority)? Create a contingency table for these two variables and store the table as special_authority_freq, then print out the result.
#
# Based on this table, do you think the variables are associated?

# %%
special_authority_freq = pd.crosstab(npi.special, npi.authority)
print(special_authority_freq)
# Out:
# authority    no   yes
# special
# no         4069  1905
# yes        2229  2894

# %%
# There is some relationsship. The so called special people do influence authority

# %% [markdown]
# ## Contingency Tables: Proportions
# In the previous exercise, we looked at an association between the influence and leader questions using a contingency table of frequencies. However, sometimes it’s helpful to convert those frequencies to proportions. We can accomplish this simply by dividing the all the frequencies in a contingency table by the total number of observations (the sum of the frequencies):

# %%
influence_leader_freq = pd.crosstab(npi.influence, npi.leader)
influence_leader_prop = influence_leader_freq/len(npi)
print(influence_leader_prop)
# Out:
# leader           no       yes
# influence
# no         0.271695  0.116518
# yes        0.212670  0.399117

# %% [markdown]
# ## Conclusions:
# The resulting contingency table makes it slightly easier to compare the proportion of people in each category. For example, we see that the two largest proportions in the table (.399 and .271) are in the yes/yes and no/no cells of the table. We can also see that almost 40% of the surveyed population (by far the largest proportion) both see themselves as leaders and think they have a talent for influencing people.

# %%
# save the table of proportions as special_authority_prop:
special_authority_freq = pd.crosstab(npi.special, npi.authority)
special_authority_prop = special_authority_freq/len(npi)


# print out special_authority_prop
print(special_authority_prop)
# Out:
# authority        no       yes
# special
# no         0.366676  0.171668
# yes        0.200865  0.260791

# %% [markdown]
# ## Marginal Proportions
# We might notice that the bottom row, which corresponds to people who think they have a talent for influencing people, accounts for 0.213 + 0.399 = 0.612 (or 61.2%) of surveyed people — more than half! This means that we can expect higher proportions in the bottom row, regardless of whether the questions are associated.
#
# The proportion of respondents in each category of a single question is called a marginal proportion. For example, the marginal proportion of the population that has a talent for influencing people is 0.612. We can calculate all the marginal proportions from the contingency table of proportions (saved as influence_leader_prop) using row and column sums as follows:

# %%
print(influence_leader_prop)
# Out:
# leader           no       yes
# influence
# no         0.271695  0.116518
# yes        0.212670  0.399117

# %%
leader_marginals = influence_leader_prop.sum(axis=0)
print(leader_marginals)
influence_marginals =  influence_leader_prop.sum(axis=1)
print(influence_marginals)
# Out:
# leader
# no     0.484365
# yes    0.515635
# dtype: float64
# influence
# no     0.388213
# yes    0.611787
# dtype: float64

# %%
# While respondents are approximately split on whether they see themselves as a leader, more people think they have a talent for influencing people than not.

# %% [markdown]
# ## Other
# The solution code from the previous exercise has been provided in script.py to create a contingency table of proportions (saved as special_authority_prop) for the special and authority columns. Use this to calculate the marginal proportions for the authority variable and save the result as authority_marginals.
#
# Print out authority_marginals. Do more people like to have authority over people or not?

# %%
# calculate and print authority_marginals
authority_marginals = special_authority_prop.sum(axis=0)
print(authority_marginals)
# Out:
# authority
# no     0.567541
# yes    0.432459
# dtype: float64

# %% [markdown]
# ## other
# Use special_authority_prop to calculate the marginal proportions for the special variable and save the result as special_marginals.
#
# Print out special_marginals. Do more people see themselves as special or not special?

# %%
# calculate and print special_marginals
special_marginals = special_authority_prop.sum(axis=1)
print(special_marginals)
# Out:
# special
# no     0.538344
# yes    0.461656
# dtype: float64

# %%
#Expected Contingency Tables

# %%
from scipy.stats import chi2_contingency
chi2, pval, dof, expected = chi2_contingency(influence_leader_freq)
print(np.round(expected))
# Out:
# [[2087. 2221.]
#  [3288. 3501.]]

# %%
# The Chi-Square Statistic

# %%
from scipy.stats import chi2_contingency
chi2, pval, dof, expected = chi2_contingency(influence_leader_freq)
print(chi2)
# Out:
# 1307.8836807573769
