# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train.csv',low_memory=False,parse_dates=['Date'])

# %%
df.head()
# Out:
#    Store  DayOfWeek       Date    Sales  Customers  Open  Promo StateHoliday  \
# 0    1.0        5.0 2015-07-31   5263.0      555.0   1.0    1.0            0
# 1    2.0        5.0 2015-07-31   6064.0      625.0   1.0    1.0            0
# 2    3.0        5.0 2015-07-31   8314.0      821.0   1.0    1.0            0
# 3    4.0        5.0 2015-07-31  13995.0     1498.0   1.0    1.0            0
# 4    5.0        5.0 2015-07-31   4822.0      559.0   1.0    1.0            0
#
#    SchoolHoliday
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Store          581438 non-null  float64
#  1   DayOfWeek      581438 non-null  float64
#  2   Date           581438 non-null  datetime64[ns]
#  3   Sales          581438 non-null  float64
#  4   Customers      581438 non-null  float64
#  5   Open           581438 non-null  float64
#  6   Promo          581438 non-null  float64
#  7   StateHoliday   581438 non-null  object
#  8   SchoolHoliday  581438 non-null  float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 69.8+ MB

# %%
dfg=df.groupby('Store')

# %%
dfg.mean()
# Out:
#         DayOfWeek         Sales    Customers      Open   Promo  SchoolHoliday
# Store
# 1.0      3.994555   3871.421053   454.914701  0.827586  0.3902       0.199637
# 2.0      3.994555   4142.963702   485.185118  0.831216  0.3902       0.174229
# 3.0      3.994555   5672.199637   607.802178  0.825771  0.3902       0.190563
# 4.0      3.994555   8156.070780  1102.384755  0.831216  0.3902       0.177858
# 5.0      3.994555   3845.996370   441.446461  0.827586  0.3902       0.172414
# ...           ...           ...          ...       ...     ...            ...
# 1111.0   3.996370   4187.693285   354.544465  0.825771  0.3902       0.190563
# 1112.0   3.996370   7916.497278   657.511797  0.825771  0.3902       0.190563
# 1113.0   3.996370   5570.257713   591.117967  0.831216  0.3902       0.170599
# 1114.0   3.996370  17437.145191  2669.791289  0.831216  0.3902       0.179673
# 1115.0   3.996370   5562.268603   377.471869  0.827586  0.3902       0.199637
#
# [1115 rows x 6 columns]

# %%
store_avg=dfg.mean().reset_index()

# %%
store_avg.plot.scatter('Store','Sales',s=3,title='Avg sale per store');

# %%
store_day=df.groupby(['Store','DayOfWeek'],as_index=False).mean()

# %%
store_day.head()
# Out:
#    Store  DayOfWeek        Sales   Customers      Open     Promo  \
# 0    1.0        1.0  4813.705128  548.679487  0.948718  0.551282
# 1    1.0        2.0  4617.329114  538.670886  0.987342  0.544304
# 2    1.0        3.0  4492.987500  529.400000  1.000000  0.537500
# 3    1.0        4.0  3975.848101  473.860759  0.911392  0.544304
# 4    1.0        5.0  4286.911392  507.594937  0.936709  0.544304
#
#    SchoolHoliday
# 0       0.217949
# 1       0.227848
# 2       0.225000
# 3       0.215190
# 4       0.227848

# %%
for
