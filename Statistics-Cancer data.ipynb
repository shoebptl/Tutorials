# %%
import pandas as pd
df=pd.read_csv('cancer_test_data.csv')

# %%
df.head()
# Out:
#    patient_id test_result  has_cancer
# 0       79452    Negative       False
# 1       81667    Positive        True
# 2       76297    Negative       False
# 3       36593    Negative       False
# 4       53717    Negative       False

# %%
df.shape[0]
# Out:
# 2914

# %%
df.query('test_result=="Positive" and has_cancer==True').shape[0]/df.query('test_result=="Positive"').shape[0]
# Out:
# 0.34282178217821785

# %%
df.query('test_result=="Positive" and has_cancer==False').shape[0]/df.query('test_result=="Positive"').shape[0]
# Out:
# 0.6571782178217822

# %%
df.query('test_result=="Negative" and has_cancer==True').shape[0]/df.query('test_result=="Negative"').shape[0]
# Out:
# 0.013770180436847104

# %%
df.query('test_result=="Negative" and has_cancer==False').shape[0]/df.query('test_result=="Negative"').shape[0]
# Out:
# 0.9862298195631529

# %%
#####

# %%
df.head(3)
# Out:
#    patient_id test_result  has_cancer
# 0       79452    Negative       False
# 1       81667    Positive        True
# 2       76297    Negative       False

# %%
df['test_result'].value_counts(normalize=True)
# Out:
# Negative    0.722718
# Positive    0.277282
# Name: test_result, dtype: float64

# %%
df['has_cancer'].value_counts(normalize=True)
# Out:
# False    0.89499
# True     0.10501
# Name: has_cancer, dtype: float64

# %%
# Creating false positive,True Negative

# %%
df.head(3)
# Out:
#    patient_id test_result  has_cancer
# 0       79452    Negative       False
# 1       81667    Positive        True
# 2       76297    Negative       False

# %%
filt=(df['has_cancer']==False) & (df['test_result']=='Positive')
df[filt]
# Out:
#       patient_id test_result  has_cancer
# 10         66393    Positive       False
# 13         56940    Positive       False
# 26         32825    Positive       False
# 32         81174    Positive       False
# 34         62481    Positive       False
# ...          ...         ...         ...
# 2902       57527    Positive       False
# 2903       72709    Positive       False
# 2904       74064    Positive       False
# 2912       61290    Positive       False
# 2913       75721    Positive       False
#
# [531 rows x 3 columns]

# %%
filt=(df['has_cancer']==True) & (df['test_result']=='Negative')
df[filt].head()
# Out:
#      patient_id test_result  has_cancer
# 82        69526    Negative        True
# 163       61222    Negative        True
# 201       34671    Negative        True
# 215       68812    Negative        True
# 342       78321    Negative        True

# %%
df.head()
# Out:
#    patient_id test_result  has_cancer
# 0       79452    Negative       False
# 1       81667    Positive        True
# 2       76297    Negative       False
# 3       36593    Negative       False
# 4       53717    Negative       False

# %%
filt=(df['has_cancer']==False) & (df['test_result']=='Negative')
df[filt]
# Out:
#       patient_id test_result  has_cancer
# 0          79452    Negative       False
# 2          76297    Negative       False
# 3          36593    Negative       False
# 4          53717    Negative       False
# 5          67134    Negative       False
# ...          ...         ...         ...
# 2907       45242    Negative       False
# 2908       41566    Negative       False
# 2909       39378    Negative       False
# 2910       58684    Negative       False
# 2911       64038    Negative       False
#
# [2077 rows x 3 columns]

# %%
filt=(df['has_cancer']==True) & (df['test_result']=='Positive')
df[filt]
# Out:
#       patient_id test_result  has_cancer
# 1          81667    Positive        True
# 7          77872    Positive        True
# 8          78761    Positive        True
# 15         56175    Positive        True
# 33         43950    Positive        True
# ...          ...         ...         ...
# 2864       53991    Positive        True
# 2871       73979    Positive        True
# 2878       47914    Positive        True
# 2887       64791    Positive        True
# 2889       53368    Positive        True
#
# [277 rows x 3 columns]

# %%
df.head(3)
# Out:
#    patient_id test_result  has_cancer
# 0       79452    Negative       False
# 1       81667    Positive        True
# 2       76297    Negative       False

# %%
v_c_result=df['test_result'].value_counts()

# %%
v_c_result
# Out:
# Negative    2106
# Positive     808
# Name: test_result, dtype: int64

# %%
df_result=pd.DataFrame(v_c_result)

# %%
df_result
# Out:
#           test_result
# Negative         2106
# Positive          808

# %%
v_c_hascancer=df['has_cancer'].value_counts()

# %%
df_cancer=pd.DataFrame(v_c_hascancer)

# %%
df_cancer
# Out:
#        has_cancer
# False        2608
# True          306

# %%
df_cancer['has_cancer'].sum()
# Out:
# 2914

# %%
(df_cancer.loc[True]/df_cancer['has_cancer'].sum())*100
# Out:
# has_cancer    10.50103
# Name: True, dtype: float64

# %%
df.head(3)
# Out:
#    patient_id test_result  has_cancer
# 0       79452    Negative       False
# 1       81667    Positive        True
# 2       76297    Negative       False
