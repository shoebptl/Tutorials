# %%
import pandas as pd

# %%
invoices = pd.read_csv('https://raw.githubusercontent.com/FBosler/you-datascientist/master/invoices.csv')

# %%
invoices.head()
# Out:
#            Order Id        Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB  2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM  2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L  2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ  2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E  2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                 Date of Meal                       Participants  Meal Price  \
# 0  2016-05-31 07:00:00+02:00                   ['David Bishop']       469.0
# 1  2018-10-01 20:00:00+02:00                   ['David Bishop']        22.0
# 2  2014-08-23 14:00:00+02:00                 ['Karen Stansell']       314.0
# 3  2014-04-07 21:00:00+02:00                   ['Addie Patino']       438.0
# 4  2015-07-27 14:00:00+02:00  ['Addie Patino' 'Susan Guerrero']       690.0
#
#   Type of Meal  Heroes Adjustment
# 0    Breakfast              False
# ...

# %%
invoices.dtypes
# Out:
# Order Id              object
# Date                  object
# Meal Id               object
# Company Id            object
# Date of Meal          object
# Participants          object
# Meal Price           float64
# Type of Meal          object
# Heroes Adjustment       bool
# dtype: object

# %%
invoices['Type of Meal'].unique()
# Out:
# array(['Breakfast', 'Dinner', 'Lunch'], dtype=object)

# %%
invoices['Type of Meal'] = invoices['Type of Meal'].astype('category')
invoices['Date'] = invoices['Date'].astype('datetime64')
invoices['Meal Price'] = invoices['Meal Price'].astype('int')

# %%
invoices.dtypes
# Out:
# Order Id                     object
# Date                 datetime64[ns]
# Meal Id                      object
# Company Id                   object
# Date of Meal                 object
# Participants                 object
# Meal Price                    int32
# Type of Meal               category
# Heroes Adjustment              bool
# dtype: object

# %%
invoices.loc[45612,'Meal Price'] = 'I am causing trouble'
invoices.loc[35612,'Meal Price'] = 'Me too'

# %%
invoices['Meal Price'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-7a45f8f5d74c> in <module>
# ----> 1 invoices['Meal Price'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
invoices['Meal Price'].apply(lambda x: type(x)).value_counts()

# %%
x='hello'
type(x)

# %%
invoices[invoices['Meal Price'].apply(
  lambda x: isinstance(x,str)
)]['Meal Price']

# %%
x = isinstance(5, int)
x

# %%
pd.to_numeric(invoices['Meal Price'], errors='coerce')

# %%
invoices[invoices['Meal Price'].apply(
  lambda x: isinstance(x,str)
)]['Meal Price']

# %%
invoices['Meal Price'] = pd.to_numeric(invoices['Meal Price'],errors='coerce')

# %%
invoices[invoices['Meal Price'].apply(
  lambda x: isinstance(x,str)
)]['Meal Price']

# %%
invoices.isnull().sum()

# %%
invoices['Meal Price'] = invoices['Meal Price'].fillna(invoices['Meal Price'].median())

# %%
invoices.isnull().sum()

# %%
invoices['Meal Price'].dtype

# %%
invoices['Meal Price']=invoices['Meal Price'].astype(int)

# %%
invoices['Meal Price'].dtype

# %%
invoices['Date'].dtype

# %%
invoices['Date of Meal'] = pd.to_datetime(invoices['Date of Meal'], utc=True)

# %%
invoices['Date'].dtype

# %%
invoices['Type of Meal'].str.lower()
# Out:
# 0        breakfast
# 1           dinner
# 2            lunch
# 3           dinner
# 4            lunch
#            ...
# 50012    breakfast
# 50013    breakfast
# 50014       dinner
# 50015       dinner
# 50016        lunch
# Name: Type of Meal, Length: 50017, dtype: object

# %%
invoices['Type of Meal'].str.zfill(width=15).head(3)
# Out:
# 0    000000Breakfast
# 1    000000000Dinner
# 2    0000000000Lunch
# Name: Type of Meal, dtype: object

# %%
invoices['Type of Meal'].str.endswith('ast').head(10)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: Type of Meal, dtype: bool

# %%
invoices[invoices['Type of Meal'].str.endswith('ast')==True]
# Out:
#                Order Id       Date           Meal Id        Company Id  \
# 0      839FKFW2LLX4LMBB 2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 7      FM608JK1N01BPUQN 2014-05-08  E8WJZ1FOSKZD2MJN  36MFTZOYMTAJP1RK
# 11     8RIGCF74GUEQHQEE 2018-07-23  5XK0KTFTD6OAP9ZP  36MFTZOYMTAJP1RK
# 12     TH60C9D8TPYS7DGG 2016-12-15  KDSMP2VJ22HNEPYF  36MFTZOYMTAJP1RK
# 17     KNF3E3QTOQ22J269 2018-06-20  737T2U7604ABDFDF  36MFTZOYMTAJP1RK
# ...                 ...        ...               ...               ...
# 50008  UHIE76EGIC2KFP34 2016-08-06  BFLY4LHHUI5OIREM  FC1LJXHNH2883N3Y
# 50009  FWH3N8N5ARW53BE6 2016-03-17  WHVI4J3J388I8I4B  FC1LJXHNH2883N3Y
# 50011  81J2RM0YM63VAT0K 2018-06-03  HNXSJZQ120WGAWZP  E4K99D4JR9E40VE1
# 50012  4OMS8ZSA0UX8LHWI 2017-09-20  1TD5MROATV1NHZ4Y  E4K99D4JR9E40VE1
# 50013  RR0VKJN8V0KHNKGG 2018-03-19  22EX9VZSJKHP4AIP  E4K99D4JR9E40VE1
#
#                     Date of Meal  \
# 0      2016-05-31 07:00:00+02:00
# 7      2014-05-07 09:00:00+02:00
# ...

# %%
invoices['Type of Meal'].cat.ordered
# Out:
# False

# %%
# joining data

# %%
y_2013 = invoices[invoices['Date of Meal'].dt.year == 2013].copy()
y_2014 = invoices[invoices['Date of Meal'].dt.year == 2014].copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-3e65c8986925> in <module>
# ----> 1 y_2013 = invoices[invoices['Date of Meal'].dt.year == 2013].copy()
#       2 y_2014 = invoices[invoices['Date of Meal'].dt.year == 2014].copy()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
# ...

# %%
# Some code from data independent

# %%
#1 Melt function
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame.from_dict({"Name": ['Liho Liho', 'Tompkins', 'The Square', 'Chambers'],
                             "8/4/2020": np.random.randint(10,200, size=(1,4))[0],
                             "8/5/2020": np.random.randint(12,200, size=(1,4))[0],
                             "8/6/2020": np.random.randint(12,200, size=(1,4))[0],
                             "8/7/2020": np.random.randint(12,200, size=(1,4))[0]}, orient='columns')
df
# Out:
#          Name  8/4/2020  8/5/2020  8/6/2020  8/7/2020
# 0   Liho Liho        98        30       141       114
# 1    Tompkins       140        87        27       100
# 2  The Square        82        53        20        95
# 3    Chambers       166       171       189        93

# %%
df.melt(id_vars='Name')
# Out:
#           Name  variable  value
# 0    Liho Liho  8/4/2020     98
# 1     Tompkins  8/4/2020    140
# 2   The Square  8/4/2020     82
# 3     Chambers  8/4/2020    166
# 4    Liho Liho  8/5/2020     30
# 5     Tompkins  8/5/2020     87
# 6   The Square  8/5/2020     53
# 7     Chambers  8/5/2020    171
# 8    Liho Liho  8/6/2020    141
# 9     Tompkins  8/6/2020     27
# 10  The Square  8/6/2020     20
# 11    Chambers  8/6/2020    189
# 12   Liho Liho  8/7/2020    114
# 13    Tompkins  8/7/2020    100
# 14  The Square  8/7/2020     95
# 15    Chambers  8/7/2020     93

# %%
df.melt(id_vars='Name', value_vars=['8/4/2020', '8/5/2020'])
# only a subset of 2 dates
# Out:
#          Name  variable  value
# 0   Liho Liho  8/4/2020     98
# 1    Tompkins  8/4/2020    140
# 2  The Square  8/4/2020     82
# 3    Chambers  8/4/2020    166
# 4   Liho Liho  8/5/2020     30
# 5    Tompkins  8/5/2020     87
# 6  The Square  8/5/2020     53
# 7    Chambers  8/5/2020    171

# %%
# customize column names

# %%
df.melt(id_vars='Name', var_name='Date', value_name='Transaction_Amount')
# Out:
#           Name      Date  Transaction_Amount
# 0    Liho Liho  8/4/2020                  98
# 1     Tompkins  8/4/2020                 140
# 2   The Square  8/4/2020                  82
# 3     Chambers  8/4/2020                 166
# 4    Liho Liho  8/5/2020                  30
# 5     Tompkins  8/5/2020                  87
# 6   The Square  8/5/2020                  53
# 7     Chambers  8/5/2020                 171
# 8    Liho Liho  8/6/2020                 141
# 9     Tompkins  8/6/2020                  27
# 10  The Square  8/6/2020                  20
# 11    Chambers  8/6/2020                 189
# 12   Liho Liho  8/7/2020                 114
# 13    Tompkins  8/7/2020                 100
# 14  The Square  8/7/2020                  95
# 15    Chambers  8/7/2020                  93

# %%
# using melt directly from pandas

# %%
pd.melt(df, id_vars='Name')
# Out:
#           Name  variable  value
# 0    Liho Liho  8/4/2020     98
# 1     Tompkins  8/4/2020    140
# 2   The Square  8/4/2020     82
# 3     Chambers  8/4/2020    166
# 4    Liho Liho  8/5/2020     30
# 5     Tompkins  8/5/2020     87
# 6   The Square  8/5/2020     53
# 7     Chambers  8/5/2020    171
# 8    Liho Liho  8/6/2020    141
# 9     Tompkins  8/6/2020     27
# 10  The Square  8/6/2020     20
# 11    Chambers  8/6/2020    189
# 12   Liho Liho  8/7/2020    114
# 13    Tompkins  8/7/2020    100
# 14  The Square  8/7/2020     95
# 15    Chambers  8/7/2020     93

# %%
# Pandas-Iterate over rows

# %%
# Method: 1

# %%
df = pd.DataFrame([('Foreign Cinema', 'Restaurant', 289.0),
                   ('Liho Liho', 'Restaurant', 224.0),
                   ('500 Club', 'bar', 80.5),
                   ('The Square', 'bar', 25.30),
                   ('The Lighthouse', 'bar', 15.30),
                   ("Al's Place", 'Restaurant', 456.53)],
           columns=('name', 'type', 'AvgBill')
                 )
df
# Out:
#              name        type  AvgBill
# 0  Foreign Cinema  Restaurant   289.00
# 1       Liho Liho  Restaurant   224.00
# 2        500 Club         bar    80.50
# 3      The Square         bar    25.30
# 4  The Lighthouse         bar    15.30
# 5      Al's Place  Restaurant   456.53

# %% [markdown]
# We are first going to use pandas apply. This will run through each row and apply a function for us. I'll use a quick lambda function for this example. Make sure you're axis=1 to go through rows.

# %%
# Printing Name and AvgBill. In this case, "x" is a series with index of column names
df.apply(lambda x: print ("{} - {}".format(x['name'], x['AvgBill'])), axis=1)
# Out:
# Foreign Cinema - 289.0
# Liho Liho - 224.0
# 500 Club - 80.5
# The Square - 25.3
# The Lighthouse - 15.3
# Al's Place - 456.53
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# dtype: object

# %%
df1=df.copy()

# %%
df1['Rounding_avg_bill']=df1['AvgBill'].apply(lambda x: round(x,1))

# %%
df1
# Out:
#              name        type  AvgBill  Rounding_avg_bill
# 0  Foreign Cinema  Restaurant   289.00              289.0
# 1       Liho Liho  Restaurant   224.00              224.0
# 2        500 Club         bar    80.50               80.5
# 3      The Square         bar    25.30               25.3
# 4  The Lighthouse         bar    15.30               15.3
# 5      Al's Place  Restaurant   456.53              456.5

# %%
# Method:2 Iterrows. Returns index and its row

# %%
for index, contents in df.iterrows():
    print(index,contents)
# Out:
# 0 name       Foreign Cinema
# type           Restaurant
# AvgBill               289
# Name: 0, dtype: object
# 1 name        Liho Liho
# type       Restaurant
# AvgBill           224
# Name: 1, dtype: object
# 2 name       500 Club
# type            bar
# AvgBill        80.5
# Name: 2, dtype: object
# 3 name       The Square
# type              bar
# AvgBill          25.3
# Name: 3, dtype: object
# 4 name       The Lighthouse
# type                  bar
# AvgBill              15.3
# Name: 4, dtype: object
# 5 name       Al's Place
# type       Restaurant
# AvgBill        456.53
# Name: 5, dtype: object

# %%
for index, contents in df.iterrows():
    print ("Index: {}".format(index))
    print ("{} - {}".format(contents['name'], contents['AvgBill']))
    print ()
# Out:
# Index: 0
# Foreign Cinema - 289.0
#
# Index: 1
# Liho Liho - 224.0
#
# Index: 2
# 500 Club - 80.5
#
# Index: 3
# The Square - 25.3
#
# Index: 4
# The Lighthouse - 15.3
#
# Index: 5
# Al's Place - 456.53

# %%
# Method: 3 datadictionary

# %%
df_dict = df.to_dict(orient='index')
df_dict
# Out:
# {0: {'name': 'Foreign Cinema', 'type': 'Restaurant', 'AvgBill': 289.0},
#  1: {'name': 'Liho Liho', 'type': 'Restaurant', 'AvgBill': 224.0},
#  2: {'name': '500 Club', 'type': 'bar', 'AvgBill': 80.5},
#  3: {'name': 'The Square', 'type': 'bar', 'AvgBill': 25.3},
#  4: {'name': 'The Lighthouse', 'type': 'bar', 'AvgBill': 15.3},
#  5: {'name': "Al's Place", 'type': 'Restaurant', 'AvgBill': 456.53}}

# %%
for key in df_dict:
    print (key)
    print (df_dict[key])
    print (df_dict[key]['name'])
    print ()
# Out:
# 0
# {'name': 'Foreign Cinema', 'type': 'Restaurant', 'AvgBill': 289.0}
# Foreign Cinema
#
# 1
# {'name': 'Liho Liho', 'type': 'Restaurant', 'AvgBill': 224.0}
# Liho Liho
#
# 2
# {'name': '500 Club', 'type': 'bar', 'AvgBill': 80.5}
# 500 Club
#
# 3
# {'name': 'The Square', 'type': 'bar', 'AvgBill': 25.3}
# The Square
#
# 4
# {'name': 'The Lighthouse', 'type': 'bar', 'AvgBill': 15.3}
# The Lighthouse
#
# 5
# {'name': "Al's Place", 'type': 'Restaurant', 'AvgBill': 456.53}
# Al's Place

# %%
# Method: 4 :using itertuples returns tuples

# %%
for row in df.itertuples():
    print (row)
    print (row.name)
    print ()
# Out:
# Pandas(Index=0, name='Foreign Cinema', type='Restaurant', AvgBill=289.0)
# Foreign Cinema
#
# Pandas(Index=1, name='Liho Liho', type='Restaurant', AvgBill=224.0)
# Liho Liho
#
# Pandas(Index=2, name='500 Club', type='bar', AvgBill=80.5)
# 500 Club
#
# Pandas(Index=3, name='The Square', type='bar', AvgBill=25.3)
# The Square
#
# Pandas(Index=4, name='The Lighthouse', type='bar', AvgBill=15.3)
# The Lighthouse
#
# Pandas(Index=5, name="Al's Place", type='Restaurant', AvgBill=456.53)
# Al's Place

# %%
# method: 4 using iloc

# %%
for i in range(len(df)):
    print (df.iloc[i])
    print ()
    print ("Name: {}".format(df.iloc[i]['name']))
    print ("\n")
# Out:
# name       Foreign Cinema
# type           Restaurant
# AvgBill               289
# Name: 0, dtype: object
#
# Name: Foreign Cinema
#
#
# name        Liho Liho
# type       Restaurant
# AvgBill           224
# Name: 1, dtype: object
#
# Name: Liho Liho
#
#
# name       500 Club
# type            bar
# AvgBill        80.5
# Name: 2, dtype: object
#
# Name: 500 Club
#
#
# name       The Square
# type              bar
# AvgBill          25.3
# Name: 3, dtype: object
#
# Name: The Square
#
#
# name       The Lighthouse
# type                  bar
# AvgBill              15.3
# Name: 4, dtype: object
#
# Name: The Lighthouse
#
#
# name       Al's Place
# type       Restaurant
# AvgBill        456.53
# Name: 5, dtype: object
#
# Name: Al's Place

# %%
x=df.iloc[0]

# %%
x
# Out:
# name       Foreign Cinema
# type           Restaurant
# AvgBill               289
# Name: 0, dtype: object

# %%
x.dtype
# Out:
# dtype('O')

# %%
x['name']
# Out:
# 'Foreign Cinema'

# %%
x['type']
# Out:
# 'Restaurant'

# %%
x['AvgBill']
# Out:
# 289.0

# %%
# just search a value of AvgBill=289 and find its row

# %%
for i in range(len(df)):
    if df.iloc[i]['AvgBill']==289:
        print('Value Found')
        print(df.iloc[i])
# Out:
# Value Found
# name       Foreign Cinema
# type           Restaurant
# AvgBill               289
# Name: 0, dtype: object

# %%
def search_column_value(df,col,val):
    for i in range(len(df)):
        if df.iloc[i][col]==val:
            return df.iloc[i]

# %%
search_column_value(df,'AvgBill',289)
# Out:
# name       Foreign Cinema
# type           Restaurant
# AvgBill               289
# Name: 0, dtype: object

# %%
search_column_value(df,'name','500 Club')
# Out:
# name       500 Club
# type            bar
# AvgBill        80.5
# Name: 2, dtype: object

# %%
df
# Out:
#              name        type  AvgBill
# 0  Foreign Cinema  Restaurant   289.00
# 1       Liho Liho  Restaurant   224.00
# 2        500 Club         bar    80.50
# 3      The Square         bar    25.30
# 4  The Lighthouse         bar    15.30
# 5      Al's Place  Restaurant   456.53

# %%
# using apply function

# %%
def print_outcome(x):
    print (type(x))
    print (x)
    print ()

# %%
df.apply(print_outcome, axis=0)
# Out:
# <class 'pandas.core.series.Series'>
# 0    Foreign Cinema
# 1         Liho Liho
# 2          500 Club
# 3        The Square
# 4    The Lighthouse
# 5        Al's Place
# Name: name, dtype: object
#
# <class 'pandas.core.series.Series'>
# 0    Restaurant
# 1    Restaurant
# 2           bar
# 3           bar
# 4           bar
# 5    Restaurant
# Name: type, dtype: object
#
# <class 'pandas.core.series.Series'>
# 0       289
# 1       224
# 2      80.5
# 3      25.3
# 4      15.3
# 5    456.53
# Name: AvgBill, dtype: object
# name       None
# type       None
# AvgBill    None
# dtype: object

# %%
df.apply(print_outcome, axis=1)
# Out:
# <class 'pandas.core.series.Series'>
# name       Foreign Cinema
# type           Restaurant
# AvgBill               289
# Name: 0, dtype: object
#
# <class 'pandas.core.series.Series'>
# name        Liho Liho
# type       Restaurant
# AvgBill           224
# Name: 1, dtype: object
#
# <class 'pandas.core.series.Series'>
# name       500 Club
# type            bar
# AvgBill        80.5
# Name: 2, dtype: object
#
# <class 'pandas.core.series.Series'>
# name       The Square
# type              bar
# AvgBill          25.3
# Name: 3, dtype: object
#
# <class 'pandas.core.series.Series'>
# name       The Lighthouse
# type                  bar
# AvgBill              15.3
# Name: 4, dtype: object
#
# <class 'pandas.core.series.Series'>
# name       Al's Place
# type       Restaurant
# AvgBill        456.53
# Name: 5, dtype: object
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# dtype: object

# %%
def combine_strings(row):
    return "{}, {}, {}".format(row['name'], row['type'], row['AvgBill'])

df.apply(combine_strings, axis=1)
# Out:
# 0    Foreign Cinema, Restaurant, 289.0
# 1         Liho Liho, Restaurant, 224.0
# 2                  500 Club, bar, 80.5
# 3                The Square, bar, 25.3
# 4            The Lighthouse, bar, 15.3
# 5       Al's Place, Restaurant, 456.53
# dtype: object

# %%
#2

# %%
flight=pd.read_csv('flight_data.csv')

# %%
flight
# Out:
#   operator_code  route_code duration
# 0           AXZ          12    2h 5m
# 1           DTR          32    3h 7m
# 2           AXZ          34    7h 3m
# 3           AXZ          12   2h 15m
# 4           YUN           8   1h 10m
# 5           YUN          12   2h 10m
# 6           YUN          13   3h 55m
# 7           DTR          16   3h 30m
# 8           DTR          18   6h 10m
# 9           AXZ          13   3h 45m

# %%
# convert duration column in minutes

# %%
d=flight['duration'][0]
d
# Out:
# '2h 5m'

# %%
d.split()
# Out:
# ['2h', '5m']

# %%
int(d.split()[0].replace('h','')) * 60
# Out:
# 120

# %%
int(d.split()[1].replace('m',''))
# Out:
# 5

# %%
int(d.split()[0].replace('h','')) * 60+int(d.split()[1].replace('m',''))
# Out:
# 125

# %%
for i,d in enumerate(flight.duration):
    dur=int(d.split()[0].replace('h','')) * 60+int(d.split()[1].replace('m',''))
    flight.loc[i,'dur_min']=dur

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min
# 0           AXZ          12    2h 5m    125.0
# 1           DTR          32    3h 7m    187.0
# 2           AXZ          34    7h 3m    423.0
# 3           AXZ          12   2h 15m    135.0
# 4           YUN           8   1h 10m     70.0
# 5           YUN          12   2h 10m    130.0
# 6           YUN          13   3h 55m    235.0
# 7           DTR          16   3h 30m    210.0
# 8           DTR          18   6h 10m    370.0
# 9           AXZ          13   3h 45m    225.0

# %%
def duration(d):
    return int(d.split()[0].replace('h','')) * 60+int(d.split()[1].replace('m',''))

# %%
flight=pd.read_csv('flight_data.csv')

# %%
flight['dur_minutes']=flight['duration'].apply(duration)

# %%
flight
# Out:
#   operator_code  route_code duration  dur_minutes
# 0           AXZ          12    2h 5m          125
# 1           DTR          32    3h 7m          187
# 2           AXZ          34    7h 3m          423
# 3           AXZ          12   2h 15m          135
# 4           YUN           8   1h 10m           70
# 5           YUN          12   2h 10m          130
# 6           YUN          13   3h 55m          235
# 7           DTR          16   3h 30m          210
# 8           DTR          18   6h 10m          370
# 9           AXZ          13   3h 45m          225

# %%
flight=pd.read_csv('flight_data.csv')

# %%
flight
# Out:
#   operator_code  route_code duration
# 0           AXZ          12    2h 5m
# 1           DTR          32    3h 7m
# 2           AXZ          34    7h 3m
# 3           AXZ          12   2h 15m
# 4           YUN           8   1h 10m
# 5           YUN          12   2h 10m
# 6           YUN          13   3h 55m
# 7           DTR          16   3h 30m
# 8           DTR          18   6h 10m
# 9           AXZ          13   3h 45m

# %%
int(flight['duration'].str.split()[0][0][:-1])* 60 + int(flight['duration'].str.split()[0][1][:-1])
# Out:
# 125

# %%
int(flight['duration'].str.split()[1][0][-2])* 60 + int(flight['duration'].str.split()[1][1][-2])
# Out:
# 187

# %%
for i in range(len(flight)):
    print(int(flight['duration'].str.split()[i][0][:-1])* 60 + int(flight['duration'].str.split()[i][1][:-1]))
# Out:
# 125
# 187
# 423
# 135
# 70
# 130
# 235
# 210
# 370
# 225

# %%
flight['dur_min']=flight['duration'].apply(lambda x:int(x.split()[0][:-1])* 60 + int(x.split()[1][:-1]))

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min
# 0           AXZ          12    2h 5m      125
# 1           DTR          32    3h 7m      187
# 2           AXZ          34    7h 3m      423
# 3           AXZ          12   2h 15m      135
# 4           YUN           8   1h 10m       70
# 5           YUN          12   2h 10m      130
# 6           YUN          13   3h 55m      235
# 7           DTR          16   3h 30m      210
# 8           DTR          18   6h 10m      370
# 9           AXZ          13   3h 45m      225

# %%
boston=pd.read_csv('boston.csv')
boston.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
for ind,row in boston.iterrows():
    boston.loc[ind,'Avg_price']=row['medv']/row['rm']

# %%
boston.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv  Avg_price
# 0  296     15.3  396.90   4.98  24.0   3.650190
# 1  242     17.8  396.90   9.14  21.6   3.363962
# 2  242     17.8  392.83   4.03  34.7   4.829506
# 3  222     18.7  394.63   2.94  33.4   4.772792
# 4  222     18.7  396.90   5.33  36.2   5.065062

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min
# 0           AXZ          12    2h 5m      125
# 1           DTR          32    3h 7m      187
# 2           AXZ          34    7h 3m      423
# 3           AXZ          12   2h 15m      135
# 4           YUN           8   1h 10m       70
# 5           YUN          12   2h 10m      130
# 6           YUN          13   3h 55m      235
# 7           DTR          16   3h 30m      210
# 8           DTR          18   6h 10m      370
# 9           AXZ          13   3h 45m      225

# %%
flight.groupby('route_code')['dur_min'].sum()
# Out:
# route_code
# 8      70
# 12    390
# 13    460
# 16    210
# 18    370
# 32    187
# 34    423
# Name: dur_min, dtype: int64

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min
# 0           AXZ          12    2h 5m      125
# 1           DTR          32    3h 7m      187
# 2           AXZ          34    7h 3m      423
# 3           AXZ          12   2h 15m      135
# 4           YUN           8   1h 10m       70
# 5           YUN          12   2h 10m      130
# 6           YUN          13   3h 55m      235
# 7           DTR          16   3h 30m      210
# 8           DTR          18   6h 10m      370
# 9           AXZ          13   3h 45m      225

# %%
mult_group=flight.groupby(['operator_code','route_code'])['dur_min'].sum()

# %%
mult_group
# Out:
# operator_code  route_code
# AXZ            12            260
#                13            225
#                34            423
# DTR            16            210
#                18            370
#                32            187
# YUN            8              70
#                12            130
#                13            235
# Name: dur_min, dtype: int64

# %%
mult_group.loc['AXZ']
# Out:
# route_code
# 12    260
# 13    225
# 34    423
# Name: dur_min, dtype: int64

# %%
mult_group.loc['AXZ'][12]
# Out:
# 260

# %%
mult_group.iloc[0]
# Out:
# 260

# %%
mult_group
# Out:
# operator_code  route_code
# AXZ            12            260
#                13            225
#                34            423
# DTR            16            210
#                18            370
#                32            187
# YUN            8              70
#                12            130
#                13            235
# Name: dur_min, dtype: int64

# %%
# find the maximum duration

# %%
mx=mult_group.idxmax()

# %%
mx
# Out:
# ('AXZ', 34)

# %%
mult_group.loc[mx[0]][mx[1]]
# Out:
# 423

# %%
# find row with max dur_min

# %%
mx=flight['dur_min'].idxmax()

# %%
flight.loc[mx]
# Out:
# operator_code      AXZ
# route_code          34
# duration         7h 3m
# dur_min            423
# Name: 2, dtype: object

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min
# 0           AXZ          12    2h 5m      125
# 1           DTR          32    3h 7m      187
# 2           AXZ          34    7h 3m      423
# 3           AXZ          12   2h 15m      135
# 4           YUN           8   1h 10m       70
# 5           YUN          12   2h 10m      130
# 6           YUN          13   3h 55m      235
# 7           DTR          16   3h 30m      210
# 8           DTR          18   6h 10m      370
# 9           AXZ          13   3h 45m      225

# %%
flight.groupby('operator_code')['dur_min'].sum()
# Out:
# operator_code
# AXZ    908
# DTR    767
# YUN    435
# Name: dur_min, dtype: int64

# %%
flight.groupby('operator_code')['dur_min'].max()
# Out:
# operator_code
# AXZ    423
# DTR    370
# YUN    235
# Name: dur_min, dtype: int64

# %%
flight.groupby('operator_code')['dur_min'].min()
# Out:
# operator_code
# AXZ    125
# DTR    187
# YUN     70
# Name: dur_min, dtype: int64

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min
# 0           AXZ          12    2h 5m      125
# 1           DTR          32    3h 7m      187
# 2           AXZ          34    7h 3m      423
# 3           AXZ          12   2h 15m      135
# 4           YUN           8   1h 10m       70
# 5           YUN          12   2h 10m      130
# 6           YUN          13   3h 55m      235
# 7           DTR          16   3h 30m      210
# 8           DTR          18   6h 10m      370
# 9           AXZ          13   3h 45m      225

# %%
fuel=pd.read_csv('fuel_econ.csv').head(20)
fuel
# Out:
#        id        make           model  year           VClass  \
# 0   32204      Nissan            GT-R  2013  Subcompact Cars
# 1   32205  Volkswagen              CC  2013     Compact Cars
# 2   32206  Volkswagen              CC  2013     Compact Cars
# 3   32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4   32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
# 5   32209       Lexus          GS 350  2013     Midsize Cars
# 6   32210       Lexus      GS 350 AWD  2013     Midsize Cars
# 7   32214     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 8   32215     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 9   32216     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 10  32217     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 11  32218  Volkswagen              CC  2013     Compact Cars
# 12  32219     Lincoln         MKS AWD  2013       Large Cars
# 13  32220     Lincoln         MKS AWD  2013       Large Cars
# ...

# %%
import pandas as pd
sr = pd.Series(['New_York', 'Lisbon', 'Texas', 'Paris', 'California'])
idx = ['City 1', 'City 2', 'City 3', 'City 4', 'City 5']

# %%
sr
# Out:
# 0      New_York
# 1        Lisbon
# 2         Texas
# 3         Paris
# 4    California
# dtype: object

# %%
result = sr.str.contains(pat = 'is')

# %%
sr[result]
# Out:
# 1    Lisbon
# 3     Paris
# dtype: object

# %%
auto=fuel['trans'].str.contains('Automatic')

# %%
fuel[auto]
# Out:
#        id        make           model  year           VClass  \
# 0   32204      Nissan            GT-R  2013  Subcompact Cars
# 1   32205  Volkswagen              CC  2013     Compact Cars
# 2   32206  Volkswagen              CC  2013     Compact Cars
# 3   32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4   32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
# 5   32209       Lexus          GS 350  2013     Midsize Cars
# 6   32210       Lexus      GS 350 AWD  2013     Midsize Cars
# 7   32214     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 9   32216     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 12  32219     Lincoln         MKS AWD  2013       Large Cars
# 13  32220     Lincoln         MKS AWD  2013       Large Cars
# 14  32221     Lincoln         MKS FWD  2013       Large Cars
# 15  32231       Mazda               6  2013     Midsize Cars
# 16  32232        Ford      Taurus AWD  2013       Large Cars
# ...

# %%
manual=fuel['trans'].str.contains('Manual')

# %%
fuel[manual]
# Out:
#        id        make          model  year           VClass  \
# 8   32215     Hyundai  Genesis Coupe  2013  Subcompact Cars
# 10  32217     Hyundai  Genesis Coupe  2013  Subcompact Cars
# 11  32218  Volkswagen             CC  2013     Compact Cars
#
#                 drive         trans          fuelType  cylinders  displ  ...  \
# 8    Rear-Wheel Drive  Manual 6-spd  Premium Gasoline          4    2.0  ...
# 10   Rear-Wheel Drive  Manual 6-spd  Premium Gasoline          6    3.8  ...
# 11  Front-Wheel Drive  Manual 6-spd  Premium Gasoline          4    2.0  ...
#
#     pv4     city    UCity  highway  UHighway     comb  co2  feScore  ghgScore  \
# 8     0  20.6741  26.2000  29.2741   41.8000  23.8235  375        6         6
# 10    0  18.1909  22.8000  26.7761   37.9000  21.2581  420        5         5
# 11    0  20.8232  25.7303  31.7255   43.9687  24.6323  360        6         6
#
#           new
# 8   Automatic
# 10  Automatic
# 11  Automatic
#
# [3 rows x 21 columns]

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min
# 0           AXZ          12    2h 5m      125
# 1           DTR          32    3h 7m      187
# 2           AXZ          34    7h 3m      423
# 3           AXZ          12   2h 15m      135
# 4           YUN           8   1h 10m       70
# 5           YUN          12   2h 10m      130
# 6           YUN          13   3h 55m      235
# 7           DTR          16   3h 30m      210
# 8           DTR          18   6h 10m      370
# 9           AXZ          13   3h 45m      225

# %%
mult_group
# Out:
# operator_code  route_code
# AXZ            12            260
#                13            225
#                34            423
# DTR            16            210
#                18            370
#                32            187
# YUN            8              70
#                12            130
#                13            235
# Name: dur_min, dtype: int64

# %%
mult_df=pd.DataFrame(mult_group)

# %%
mult_df.reset_index()
# Out:
#   operator_code  route_code  dur_min
# 0           AXZ          12      260
# 1           AXZ          13      225
# 2           AXZ          34      423
# 3           DTR          16      210
# 4           DTR          18      370
# 5           DTR          32      187
# 6           YUN           8       70
# 7           YUN          12      130
# 8           YUN          13      235

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min
# 0           AXZ          12    2h 5m      125
# 1           DTR          32    3h 7m      187
# 2           AXZ          34    7h 3m      423
# 3           AXZ          12   2h 15m      135
# 4           YUN           8   1h 10m       70
# 5           YUN          12   2h 10m      130
# 6           YUN          13   3h 55m      235
# 7           DTR          16   3h 30m      210
# 8           DTR          18   6h 10m      370
# 9           AXZ          13   3h 45m      225

# %%
d_list=flight['duration'].to_list()

# %%
d_list
# Out:
# ['2h 5m',
#  '3h 7m',
#  '7h 3m',
#  '2h 15m',
#  '1h 10m',
#  '2h 10m',
#  '3h 55m',
#  '3h 30m',
#  '6h 10m',
#  '3h 45m']

# %%
d_min=[]
for val in d_list:
    result=0
    h,m=val.split()
    result=int(h[:-1])*60+int(m[:-1])
    d_min.append(result)
d_min
# Out:
# [125, 187, 423, 135, 70, 130, 235, 210, 370, 225]

# %%
flight['new_col']=d_min

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min  new_col
# 0           AXZ          12    2h 5m      125      125
# 1           DTR          32    3h 7m      187      187
# 2           AXZ          34    7h 3m      423      423
# 3           AXZ          12   2h 15m      135      135
# 4           YUN           8   1h 10m       70       70
# 5           YUN          12   2h 10m      130      130
# 6           YUN          13   3h 55m      235      235
# 7           DTR          16   3h 30m      210      210
# 8           DTR          18   6h 10m      370      370
# 9           AXZ          13   3h 45m      225      225

# %%
new_s=pd.Series(d_min)
flight['new_col2']=new_s.values

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min  new_col  new_col2
# 0           AXZ          12    2h 5m      125      125       125
# 1           DTR          32    3h 7m      187      187       187
# 2           AXZ          34    7h 3m      423      423       423
# 3           AXZ          12   2h 15m      135      135       135
# 4           YUN           8   1h 10m       70       70        70
# 5           YUN          12   2h 10m      130      130       130
# 6           YUN          13   3h 55m      235      235       235
# 7           DTR          16   3h 30m      210      210       210
# 8           DTR          18   6h 10m      370      370       370
# 9           AXZ          13   3h 45m      225      225       225

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min  new_col  new_col2
# 0           AXZ          12    2h 5m      125      125       125
# 1           DTR          32    3h 7m      187      187       187
# 2           AXZ          34    7h 3m      423      423       423
# 3           AXZ          12   2h 15m      135      135       135
# 4           YUN           8   1h 10m       70       70        70
# 5           YUN          12   2h 10m      130      130       130
# 6           YUN          13   3h 55m      235      235       235
# 7           DTR          16   3h 30m      210      210       210
# 8           DTR          18   6h 10m      370      370       370
# 9           AXZ          13   3h 45m      225      225       225

# %%
flight.drop('new_col',axis=1,inplace=True)

# %%
flight.drop('new_col2',axis=1,inplace=True)

# %%
flight
# Out:
#   operator_code  route_code duration  dur_min
# 0           AXZ          12    2h 5m      125
# 1           DTR          32    3h 7m      187
# 2           AXZ          34    7h 3m      423
# 3           AXZ          12   2h 15m      135
# 4           YUN           8   1h 10m       70
# 5           YUN          12   2h 10m      130
# 6           YUN          13   3h 55m      235
# 7           DTR          16   3h 30m      210
# 8           DTR          18   6h 10m      370
# 9           AXZ          13   3h 45m      225

# %%
flight['operator_code'].value_counts()
# Out:
# AXZ    4
# YUN    3
# DTR    3
# Name: operator_code, dtype: int64

# %%
flight['operator_code'].value_counts()
# Out:
# AXZ    4
# YUN    3
# DTR    3
# Name: operator_code, dtype: int64

# %%
fuel=pd.read_csv('fuel_econ.csv').head(20)

# %%
fuel['type']=fuel['trans'].apply(lambda x: x.split(' ')[0])

# %%
fuel
# Out:
#        id        make           model  year           VClass  \
# 0   32204      Nissan            GT-R  2013  Subcompact Cars
# 1   32205  Volkswagen              CC  2013     Compact Cars
# 2   32206  Volkswagen              CC  2013     Compact Cars
# 3   32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4   32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
# 5   32209       Lexus          GS 350  2013     Midsize Cars
# 6   32210       Lexus      GS 350 AWD  2013     Midsize Cars
# 7   32214     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 8   32215     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 9   32216     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 10  32217     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 11  32218  Volkswagen              CC  2013     Compact Cars
# 12  32219     Lincoln         MKS AWD  2013       Large Cars
# 13  32220     Lincoln         MKS AWD  2013       Large Cars
# ...
