# %% [markdown]
# Plot With Pandas: Python Data Visualisation For Beginners

# %% [markdown]
# This notebook contains all the code seen in the video course.  Run each cell in turn to generate the plots seen in the videos.

# %% [markdown]
# ## Set Up Your Environment

# %%
import pandas as pd

# %%
download_url = "http://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv"

# %% [markdown]
# If the following line generates an SSL error, you may need to update your certificates for your Python installation.  The method of doing this depends on the operating system you are using.

# %%
df = pd.read_csv(download_url)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option("display.max.columns", None)

# %%
df.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#    Full_time  Part_time  Full_time_year_round  Unemployed  Unemployment_rate  \
# ...

# %%
df.head(10)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %% [markdown]
# ## Create Your First Pandas Plot

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# Generally you will need to restart your notebook kernel to change backends, once one has been selected, so if you want to run in inline or notebook (interactive) mode, then alter the cell below appropriately, and run it instead of the cell above.

# %%
# %matplotlib notebook

# %%
df.plot(x="Rank", y=["P25th", "Median", "P75th"])
# Out:
# <AxesSubplot:xlabel='Rank'>

# %%
df.plot(x="Rank")
# Out:
# <AxesSubplot:xlabel='Rank'>

# %% [markdown]
# ## Look Under the Hood: Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["Rank"], df["P75th"])

# %%
df.plot(x="Rank", y="P75th")
# Out:
# <AxesSubplot:xlabel='Rank'>

# %% [markdown]
# ## Survey Your Data

# %%
median_column = df["Median"]

# %%
type(median_column)
# Out:
# pandas.core.series.Series

# %%
median_column.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
top_5 = df.sort_values(by="Median", ascending=False).head()

# %%
top_5.plot(x="Major", y="Median", kind="bar")
# Out:
# <AxesSubplot:xlabel='Major'>

# %%
top_5.plot(x="Major", y="Median", kind="bar", rot=5, fontsize=4)
# Out:
# <AxesSubplot:xlabel='Major'>

# %%
top_medians = df[df["Median"] > 60000].sort_values("Median")

# %%
top_medians.plot(x="Major", y=["P25th", "Median", "P75th"], kind="bar", rot=10, fontsize=6)
# Out:
# <AxesSubplot:xlabel='Major'>

# %% [markdown]
# ## Check for Correlation

# %%
df.plot(x="Median", y="Unemployment_rate", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Median', ylabel='Unemployment_rate'>

# %%
df.corr()
# Out:
#                           Rank  Major_code     Total       Men     Women  \
# Rank                  1.000000    0.108429  0.071137 -0.094780  0.174913
# Major_code            0.108429    1.000000  0.196784  0.179299  0.181459
# Total                 0.071137    0.196784  1.000000  0.878088  0.944764
# Men                  -0.094780    0.179299  0.878088  1.000000  0.672759
# Women                 0.174913    0.181459  0.944764  0.672759  1.000000
# ShareWomen            0.643781    0.259211  0.142999 -0.112014  0.297832
# Sample_size           0.008492    0.206580  0.945575  0.875176  0.862606
# Employed              0.070751    0.200925  0.996214  0.870605  0.944037
# Full_time             0.034725    0.199397  0.989339  0.893563  0.917681
# Part_time             0.193174    0.195184  0.950268  0.751592  0.954513
# Full_time_year_round  0.020418    0.205634  0.981112  0.892454  0.905720
# Unemployed            0.090078    0.223418  0.974768  0.869411  0.911694
# ...

# %%
plt.matshow(df.corr())

# %% [markdown]
# ## Analyze Categorical Data

# %%
cat_totals = df.groupby("Major_category")["Total"].sum().sort_values()

# %%
cat_totals
# Out:
# Major_category
# Interdisciplinary                        12296.0
# Agriculture & Natural Resources          75620.0
# Law & Public Policy                     179107.0
# Physical Sciences                       185479.0
# Industrial Arts & Consumer Services     229792.0
# Computers & Mathematics                 299008.0
# Arts                                    357130.0
# Communications & Journalism             392601.0
# Biology & Life Science                  453862.0
# Health                                  463230.0
# Psychology & Social Work                481007.0
# Social Science                          529966.0
# Engineering                             537583.0
# Education                               559129.0
# Humanities & Liberal Arts               713468.0
# Business                               1302376.0
# Name: Total, dtype: float64

# %%
cat_totals.plot(kind="barh", fontsize=8)
# Out:
# <AxesSubplot:ylabel='Major_category'>

# %%
cat_totals.plot(kind="pie", label="")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Determining Ratios

# %%
small_cat_totals = cat_totals[cat_totals < 100000]

# %%
big_cat_totals = cat_totals[cat_totals > 100000]

# %%
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])

# %%
big_cat_totals = big_cat_totals.append(small_sums)

# %%
big_cat_totals.plot(kind="pie", label="")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Zooming In on Categories

# %%
df[df["Major_category"] == "Engineering"]["Median"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# China Data (blue bars)
n = 1  # This is our first dataset (out of 2)
t = 2 # Number of datasets
d = 7 # Number of sets of bars
w = 0.8 # Width of each bar
x_values1 = [t*element + w*n for element
             in range(d)]
x_values1
# Out:
# [0.8, 2.8, 4.8, 6.8, 8.8, 10.8, 12.8]

# %%
lst=[0.8]
inc=2
for i in range(1,7):
    
    val=lst[0]+inc
    
    lst.append(val)
    inc=inc+2
print(lst)
# Out:
# [0.8, 2.8, 4.8, 6.8, 8.8, 10.8, 12.8]

# %%
import matplotlib.pyplot as plt
video_game_hours = [1, 2, 2, 1, 2]
 
plt.bar(range(len(video_game_hours)),
  video_game_hours)
# Out:
# <BarContainer object of 5 artists>

# %%
book_hours = [2, 3, 4, 2, 1]
 
plt.bar(range(len(book_hours)),
  book_hours,
  bottom=video_game_hours)
# Out:
# <BarContainer object of 5 artists>

# %%
values = [10, 13, 11, 15, 20]
yerr = 2
plt.bar(range(len(values)), values, yerr=yerr, capsize=10)
plt.show()

# %%
values = [10, 13, 11, 15, 20]
yerr = [1, 3, 0.5, 2, 4]
plt.bar(range(len(values)), values, yerr=yerr, capsize=10)
plt.show()

# %%
x_values = range(10)
y_values = [10, 12, 13, 13, 15, 19, 20, 22, 23, 29]
y_lower = [8, 10, 11, 11, 13, 17, 18, 20, 21, 27]
y_upper = [12, 14, 15, 15, 17, 21, 22, 24, 25, 31]
 
plt.fill_between(x_values, y_lower, y_upper, alpha=0.2) #this is the shaded error
plt.plot(x_values, y_values) #this is the line itself
plt.show()
