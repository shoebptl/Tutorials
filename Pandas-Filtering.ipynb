# %%
import pandas as pd
fortune=pd.read_csv('fortune1000.csv',index_col='Rank')
fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
max_revenue=fortune['Revenue'].max()
min_revenu=fortune['Revenue'].min()

# %%
# All Technology companies located in Seattle
filt1=(fortune['Sector']=='Technology') & (fortune['Location']=='Seattle, WA')

# %%
fortune[filt1]
# Out:
#           Company      Sector                                    Industry  \
# Rank
# 18     Amazon.com  Technology             Internet Services and Retailing
# 990   F5 Networks  Technology  Network and Other Communications Equipment
#
#          Location  Revenue  Profits  Employees
# Rank
# 18    Seattle, WA   107006      596     230800
# 990   Seattle, WA     1920      365       4178

# %%
# Details of Microsoft
filt2=fortune['Company']=='Microsoft'
fortune[filt2]
# Out:
#         Company      Sector           Industry     Location  Revenue  Profits  \
# Rank
# 25    Microsoft  Technology  Computer Software  Redmond, WA    93580    12193
#
#       Employees
# Rank
# 25       118000

# %%
fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
#  Group by sector

# %%
sector=fortune.groupby('Sector')
print(sector)

# %%
rev_sector=fortune.groupby('Sector')['Revenue']
for name,rev in rev_sector:
    print(name)
    print(rev)
# Out:
# Aerospace & Defense
# Rank
# 24     96114
# 45     61047
# 60     46132
# 88     31469
# 118    23526
# 120    23247
# 209    13423
# 245    11554
# 282    10056
# 378     7020
# 389     6644
# 490     5262
# 560     4369
# 605     3889
# 785     2730
# 788     2707
# 836     2526
# 903     2264
# 958     2038
# 987     1923
# Name: Revenue, dtype: int64
# Apparel
# Rank
# 91     30601
# 231    12377
# 340     8020
# 354     7620
# 448     5732
# 547     4495
# 575     4192
# 597     3963
# 683     3229
# 695     3159
# 726     3014
# 794     2692
# 877     2344
# 882     2326
# 917     2204
# Name: Revenue, dtype: int64
# Business Services
# Rank
# 144    19330
# 186    15134
# 199    14329
# 204    13880
# 221    12961
# 248    11477
# 249    11451
# 294     9667
# 307     9248
# 312     9115
# 355     7614
# 392     6595
# 404     6440
# 440     5817
# 467     5518
# 468     5484
# 481     5313
# 485     5291
# 492     5254
# 503     5095
# 545     4508
# 626     3645
# ...

# %%
max_rev_sector=fortune.groupby('Sector')['Revenue'].max()

# %%
max_rev_sector
# Out:
# Sector
# Aerospace & Defense              96114
# Apparel                          30601
# Business Services                19330
# Chemicals                        48778
# Energy                          246204
# Engineering & Construction       18114
# Financials                      210821
# Food and Drug Stores            153290
# Food, Beverages & Tobacco        67702
# Health Care                     181241
# Hotels, Resturants & Leisure     25413
# Household Products               78756
# Industrials                     140389
# Materials                        22534
# Media                            52465
# Motor Vehicles & Parts          152356
# Retailing                       482130
# Technology                      233715
# Telecommunications              146801
# Transportation                   58363
# Wholesalers                      48681
# Name: Revenue, dtype: int64

# %%
for name,rev in rev_sector:
    if name=='Media':
        print(rev)
# Out:
# Rank
# 53     52465
# 96     28987
# 99     28118
# 203    13886
# 213    13268
# 255    11257
# 327     8633
# 366     7246
# 406     6394
# 414     6242
# 525     4795
# 530     4678
# 681     3242
# 705     3127
# 707     3103
# 722     3018
# 741     2966
# 752     2885
# 759     2858
# 762     2853
# 821     2581
# 913     2219
# 968     2011
# 969     2011
# 989     1921
# Name: Revenue, dtype: int64

# %%
min_rev_sector=fortune.groupby('Sector')['Revenue'].min()
min_rev_sector
# Out:
# Sector
# Aerospace & Defense             1923
# Apparel                         2204
# Business Services               1910
# Chemicals                       2084
# Energy                          1898
# Engineering & Construction      1909
# Financials                      1902
# Food and Drug Stores            2151
# Food, Beverages & Tobacco       2066
# Health Care                     1987
# Hotels, Resturants & Leisure    1896
# Household Products              1914
# Industrials                     1895
# Materials                       1924
# Media                           1921
# Motor Vehicles & Parts          1986
# Retailing                       1999
# Technology                      1920
# Telecommunications              2726
# Transportation                  1995
# Wholesalers                     1917
# Name: Revenue, dtype: int64

# %%
# Give maximum and minimum number of employees in each sector

# %%
max_employee_sector=fortune.groupby('Sector')['Employees'].max()
max_employee_sector.sort_values(ascending=False).head()
# Out:
# Sector
# Retailing                       2300000
# Hotels, Resturants & Leisure     505000
# Food and Drug Stores             431000
# Technology                       411798
# Transportation                   341240
# Name: Employees, dtype: int64

# %%
min_employee_sector=fortune.groupby('Sector')['Employees'].min()
min_employee_sector.sort_values().head(5)
# Out:
# Sector
# Materials                       52
# Financials                     187
# Energy                         480
# Wholesalers                    500
# Engineering & Construction    1036
# Name: Employees, dtype: int64

# %%
fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
mask1=fortune['Industry'].str.contains('Health')
filt1=fortune[mask1]

# %%
filt1
# Out:
#                       Company       Sector  \
# Rank
# 5                    McKesson  Health Care
# 6          UnitedHealth Group  Health Care
# 12          AmerisourceBergen  Health Care
# 21            Cardinal Health  Health Care
# 22    Express Scripts Holding  Health Care
# ...                       ...          ...
# 925       Knights of Columbus   Financials
# 926         Symetra Financial   Financials
# 935                       VCA  Health Care
# 960                PharMerica  Health Care
# 978        Providence Service  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
# 6      Health Care: Insurance and Managed Care     Minnetonka, MN   157107
# 12                    Wholesalers: Health Care   Chesterbrook, PA   135962
# 21                    Wholesalers: Health Care         Dublin, OH   102531
# ...

# %%
mask2=fortune['Industry'].str.match('Wholesalers: Health Care')
filt2=fortune[mask2]
filt2
# Out:
#                 Company       Sector                  Industry  \
# Rank
# 5              McKesson  Health Care  Wholesalers: Health Care
# 12    AmerisourceBergen  Health Care  Wholesalers: Health Care
# 21      Cardinal Health  Health Care  Wholesalers: Health Care
# 268        Henry Schein  Health Care  Wholesalers: Health Care
# 291       Owens & Minor  Health Care  Wholesalers: Health Care
# 559           Patterson  Health Care  Wholesalers: Health Care
#
#                 Location  Revenue  Profits  Employees
# Rank
# 5      San Francisco, CA   181241     1476      70400
# 12      Chesterbrook, PA   135962     -135      17000
# 21            Dublin, OH   102531     1215      34500
# 268         Melville, NY    10630      479      19000
# 291   Mechanicsville, VA     9773      103       8100
# 559         St. Paul, MN     4375      223       7000

# %%
mask3=fortune['Industry'].str.match('Wholesalers: Health Care') 
mask4=fortune['Revenue']>100000
filt4=fortune[mask3 & mask4]
filt4
# Out:
#                 Company       Sector                  Industry  \
# Rank
# 5              McKesson  Health Care  Wholesalers: Health Care
# 12    AmerisourceBergen  Health Care  Wholesalers: Health Care
# 21      Cardinal Health  Health Care  Wholesalers: Health Care
#
#                Location  Revenue  Profits  Employees
# Rank
# 5     San Francisco, CA   181241     1476      70400
# 12     Chesterbrook, PA   135962     -135      17000
# 21           Dublin, OH   102531     1215      34500

# %%
mask5=fortune['Industry'].str.match('Wholesalers: Health Care')
filt5=fortune[mask2]
filt5[['Industry','Revenue','Employees']]
# Out:
#                       Industry  Revenue  Employees
# Rank
# 5     Wholesalers: Health Care   181241      70400
# 12    Wholesalers: Health Care   135962      17000
# 21    Wholesalers: Health Care   102531      34500
# 268   Wholesalers: Health Care    10630      19000
# 291   Wholesalers: Health Care     9773       8100
# 559   Wholesalers: Health Care     4375       7000

# %%
fortune.iloc[[11]]
# Out:
#                 Company       Sector                  Industry  \
# Rank
# 12    AmerisourceBergen  Health Care  Wholesalers: Health Care
#
#               Location  Revenue  Profits  Employees
# Rank
# 12    Chesterbrook, PA   135962     -135      17000

# %%
# Walmart Dataset

# %%
import pandas as pd
sales=pd.read_csv('sales.csv')
sales.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
sales.sort_values('date')
# Out:
#        Unnamed: 0  store type  department        date  weekly_sales  \
# 0               0      1    A           1  2010-02-05      24924.50
# 6437         6437     19    A          13  2010-02-05      38597.52
# 1249         1249      2    A          31  2010-02-05       3840.21
# 6449         6449     19    A          14  2010-02-05      17590.59
# 6461         6461     19    A          16  2010-02-05       4929.87
# ...           ...    ...  ...         ...         ...           ...
# 3592         3592      6    A          99  2012-10-05        440.00
# 8108         8108     20    A          99  2012-10-05        660.00
# 10773       10773     39    A          99  2012-10-05        915.00
# 6257         6257     14    A          96  2012-10-12          3.00
# 3384         3384      6    A          77  2012-10-26        -21.63
#
#        is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0           False       5.727778              0.679451         8.106
# ...

# %%
sales.columns
# Out:
# Index(['Unnamed: 0', 'store', 'type', 'department', 'date', 'weekly_sales',
#        'is_holiday', 'temperature_c', 'fuel_price_usd_per_l', 'unemployment'],
#       dtype='object')

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=10774, step=1)

# %%
# Date range sales

# %%
mask1=(sales['date'] >='2010-02-05') & (sales['date']<='2010-02-06')

# %%
filt1=sales[mask1]
filt1
# Out:
#        Unnamed: 0  store type  department        date  weekly_sales  \
# 0               0      1    A           1  2010-02-05      24924.50
# 12             12      1    A           2  2010-02-05      50605.27
# 24             24      1    A           3  2010-02-05      13740.12
# 36             36      1    A           4  2010-02-05      39954.04
# 48             48      1    A           5  2010-02-05      32229.38
# ...           ...    ...  ...         ...         ...           ...
# 10703       10703     39    A          94  2010-02-05      50121.73
# 10715       10715     39    A          95  2010-02-05      88385.24
# 10727       10727     39    A          96  2010-02-05      21450.05
# 10739       10739     39    A          97  2010-02-05      21162.05
# 10751       10751     39    A          98  2010-02-05       9023.09
#
#        is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0           False       5.727778              0.679451         8.106
# ...

# %%
# sales filtering

# %%
mask20=(sales['type']=='B') & (sales['weekly_sales']>200000)
filt20=sales[mask20]
filt20
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 4271        4271     10    B          72  2010-02-05     232558.51
# 4281        4281     10    B          72  2010-12-03     218559.54
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 4271       False      12.411111              0.782478         9.765
# 4281       False      10.650000              0.803348         9.003

# %%
mask21=(sales['type']=='A') & (sales['weekly_sales']>200000)
filt21=sales[mask21]
filt21
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 6201        6201     14    A          92  2010-02-05     293966.05
# 6202        6202     14    A          92  2010-03-05     214383.07
# 6203        6203     14    A          92  2010-04-02     203457.42
# 6204        6204     14    A          92  2010-05-07     206160.36
# 6207        6207     14    A          92  2010-08-06     204695.13
# 6210        6210     14    A          92  2010-11-05     206935.29
# 6237        6237     14    A          95  2010-02-05     213042.66
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 6201       False      -2.605556              0.735455         8.992
# 6202       False       2.850000              0.733606         8.992
# 6203       False       8.744444              0.752891         8.899
# 6204       False      21.527778              0.783535         8.899
# 6207       False      25.094444              0.735455         8.743
# ...

# %%
mask22=sales['temperature_c']<0
filt22=sales.loc[mask22,['weekly_sales','temperature_c']]
filt22
# Out:
#       weekly_sales  temperature_c
# 2315        498.00      -1.755556
# 2492          1.00      -1.755556
# 4495      46761.90      -0.261111
# 4505      47101.26      -3.444444
# 4506      24627.06      -8.366667
# ...            ...            ...
# 8938      74898.99      -2.672222
# 8950     133147.07      -2.672222
# 8962      17209.14      -2.672222
# 8974      25806.87      -2.672222
# 8986      13579.67      -2.672222
#
# [750 rows x 2 columns]

# %%
mask23=sales['temperature_c']>20
filt23=sales.loc[mask23,['weekly_sales','temperature_c']]
filt23
# Out:
#        weekly_sales  temperature_c
# 3          17413.94      22.527778
# 4          17558.09      27.050000
# 5          16333.14      27.172222
# 6          17508.41      30.644444
# 7          16241.78      27.338889
# ...             ...            ...
# 10766         40.00      20.416667
# 10767        622.00      31.072222
# 10771        450.00      27.288889
# 10772          0.06      25.644444
# 10773        915.00      22.250000
#
# [4671 rows x 2 columns]
