# %%
# chapter:56

# %%
import numpy as np 
import pandas as pd 
s1 = pd.Series(index=['a', 'b', 'c', 'd'], data=[0, 1, 2, 3]) 
s2 = s1.copy()

# %%
s1
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
s2
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
s1+s2
# Out:
# a    0
# b    2
# c    4
# d    6
# dtype: int64

# %%
s3 = pd.Series(index=['d', 'c', 'b', 'a'], data=[0, 1, 2, 3]) 
s3
# Out:
# d    0
# c    1
# b    2
# a    3
# dtype: int64

# %%
s1
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
s1+s3
# Out:
# a    3
# b    3
# c    3
# d    3
# dtype: int64

# %%
a=np.arange(4)
a
# Out:
# array([0, 1, 2, 3])

# %%
s1+a
# Out:
# a    0
# b    2
# c    4
# d    6
# dtype: int64

# %%
s3+a
# Out:
# d    0
# c    2
# b    4
# a    6
# dtype: int64

# %%
a=np.arange(5)

# %%
try:
    s1 + a 
except Exception as e: 
    print(type(e), e)
# Out:
# <class 'ValueError'> operands could not be broadcast together with shapes (4,) (5,)

# %%
s1 = pd.Series(index=['a', 'b', 'c', 'd'], data=[0, 1, 2, 3]) 
s2 = pd.Series(index=['a', 'b', 'c'], data=[0, 1, 2])

# %%
s1
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
s2
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
s1+s2
# Out:
# a    0.0
# b    2.0
# c    4.0
# d    NaN
# dtype: float64

# %%
s1 = pd.Series(index=['a', 'b', 'c', 'd'], data=[0, 1, 2, 3]) 
s2 = pd.Series(index=['a', 'b', 'c', 'e'], data=[0, 1, 2, 3])

# %%
s1
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
s2
# Out:
# a    0
# b    1
# c    2
# e    3
# dtype: int64

# %%
s1+s2
# Out:
# a    0.0
# b    2.0
# c    4.0
# d    NaN
# e    NaN
# dtype: float64

# %%
s1 = pd.Series(index=['a', 'a', 'a', 'b', 'b', 'b', 'c', 'c', 'c', 'c', 'd'], data=np.arange(11)) 
s1
# Out:
# a     0
# a     1
# a     2
# b     3
# b     4
# b     5
# c     6
# c     7
# c     8
# c     9
# d    10
# dtype: int32

# %%
s2 = pd.Series(index=['a', 'a', 'a', 'b', 'b', 'c', 'e'], data=np.arange(7))
s2
# Out:
# a    0
# a    1
# a    2
# b    3
# b    4
# c    5
# e    6
# dtype: int32

# %%
s1+s2
# Out:
# a     0.0
# a     1.0
# a     2.0
# a     1.0
# a     2.0
# a     3.0
# a     2.0
# a     3.0
# a     4.0
# b     6.0
# b     7.0
# b     7.0
# b     8.0
# b     8.0
# b     9.0
# c    11.0
# c    12.0
# c    13.0
# c    14.0
# d     NaN
# e     NaN
# dtype: float64

# %%
df1 = pd.DataFrame(data={'first': np.arange(4), 'second': np.arange(4)}, index=['a', 'b', 'c', 'd']) 
df1
# Out:
#    first  second
# a      0       0
# b      1       1
# c      2       2
# d      3       3

# %%
df2 = df1.copy()

# %%
df2
# Out:
#    first  second
# a      0       0
# b      1       1
# c      2       2
# d      3       3

# %%
df1+df2
# Out:
#    first  second
# a      0       0
# b      2       2
# c      4       4
# d      6       6

# %%
df1 = pd.DataFrame(data={'first': np.arange(4), 'second': np.arange(4)}, index=['a', 'b', 'c', 'd'])

# %%
df1
# Out:
#    first  second
# a      0       0
# b      1       1
# c      2       2
# d      3       3

# %%
df2 = pd.DataFrame(data={'first': np.arange(4), 'second': np.arange(4)}, index=['a', 'b', 'c', 'e'])

# %%
df2
# Out:
#    first  second
# a      0       0
# b      1       1
# c      2       2
# e      3       3

# %%
df1+df2
# Out:
#    first  second
# a    0.0     0.0
# b    2.0     2.0
# c    4.0     4.0
# d    NaN     NaN
# e    NaN     NaN

# %%
df1 = pd.DataFrame(data={'first': np.arange(4), 'second': np.arange(4)}, index=['a', 'b', 'c', 'd']) 
df2 = pd.DataFrame(data={'first': np.arange(4), 'third': np.arange(4)}, index=['a', 'b', 'c', 'e'])

# %%
df1
# Out:
#    first  second
# a      0       0
# b      1       1
# c      2       2
# d      3       3

# %%
df2
# Out:
#    first  third
# a      0      0
# b      1      1
# c      2      2
# e      3      3

# %%
df1+df2
# Out:
#    first  second  third
# a    0.0     NaN    NaN
# b    2.0     NaN    NaN
# c    4.0     NaN    NaN
# d    NaN     NaN    NaN
# e    NaN     NaN    NaN

# %%
# chapter: 57

# %%
import pandas as pd 
amzn = pd.read_csv('amzn_sample.csv', parse_dates=['date']) 
aapl = pd.read_csv('aapl_sample.csv', parse_dates=['date'])

# %%
amzn
# Out:
#         date  adjusted_close     volume
# 0 2018-03-23         1495.56  7843966.0
# 1 2018-03-26         1555.86  5547618.0
# 2 2018-03-27         1497.05  6793279.0

# %%
aapl
# Out:
#         date  adjusted_close      volume
# 0 2018-03-23          164.94  40248954.0
# 1 2018-03-26          172.77  36272617.0
# 2 2018-03-27          168.34  38962839.0

# %%
 pd.concat([amzn, aapl])
# Out:
#         date  adjusted_close      volume
# 0 2018-03-23         1495.56   7843966.0
# 1 2018-03-26         1555.86   5547618.0
# 2 2018-03-27         1497.05   6793279.0
# 0 2018-03-23          164.94  40248954.0
# 1 2018-03-26          172.77  36272617.0
# 2 2018-03-27          168.34  38962839.0

# %%
pd.concat([amzn, aapl], ignore_index=True)
# Out:
#         date  adjusted_close      volume
# 0 2018-03-23         1495.56   7843966.0
# 1 2018-03-26         1555.86   5547618.0
# 2 2018-03-27         1497.05   6793279.0
# 3 2018-03-23          164.94  40248954.0
# 4 2018-03-26          172.77  36272617.0
# 5 2018-03-27          168.34  38962839.0

# %%
pd.concat([amzn, aapl], keys=['amzn', 'aapl'])
# Out:
#              date  adjusted_close      volume
# amzn 0 2018-03-23         1495.56   7843966.0
#      1 2018-03-26         1555.86   5547618.0
#      2 2018-03-27         1497.05   6793279.0
# aapl 0 2018-03-23          164.94  40248954.0
#      1 2018-03-26          172.77  36272617.0
#      2 2018-03-27          168.34  38962839.0

# %%
amzn['symbol'] = 'amzn' 
aapl['symbol'] = 'aapl' 
pd.concat([amzn, aapl])
# Out:
#         date  adjusted_close      volume symbol
# 0 2018-03-23         1495.56   7843966.0   amzn
# 1 2018-03-26         1555.86   5547618.0   amzn
# 2 2018-03-27         1497.05   6793279.0   amzn
# 0 2018-03-23          164.94  40248954.0   aapl
# 1 2018-03-26          172.77  36272617.0   aapl
# 2 2018-03-27          168.34  38962839.0   aapl

# %%
 amzn2 = amzn.rename(columns={'Adj. Close': 'close'}) 
pd.concat([amzn2, aapl])
# Out:
#         date  adjusted_close      volume symbol
# 0 2018-03-23         1495.56   7843966.0   amzn
# 1 2018-03-26         1555.86   5547618.0   amzn
# 2 2018-03-27         1497.05   6793279.0   amzn
# 0 2018-03-23          164.94  40248954.0   aapl
# 1 2018-03-26          172.77  36272617.0   aapl
# 2 2018-03-27          168.34  38962839.0   aapl

# %%
amzn2
# Out:
#         date  adjusted_close     volume symbol
# 0 2018-03-23         1495.56  7843966.0   amzn
# 1 2018-03-26         1555.86  5547618.0   amzn
# 2 2018-03-27         1497.05  6793279.0   amzn

# %%
aapl
# Out:
#         date  adjusted_close      volume symbol
# 0 2018-03-23          164.94  40248954.0   aapl
# 1 2018-03-26          172.77  36272617.0   aapl
# 2 2018-03-27          168.34  38962839.0   aapl

# %%
pd.concat([amzn2, aapl])
# Out:
#         date  adjusted_close      volume symbol
# 0 2018-03-23         1495.56   7843966.0   amzn
# 1 2018-03-26         1555.86   5547618.0   amzn
# 2 2018-03-27         1497.05   6793279.0   amzn
# 0 2018-03-23          164.94  40248954.0   aapl
# 1 2018-03-26          172.77  36272617.0   aapl
# 2 2018-03-27          168.34  38962839.0   aapl

# %%
pd.concat([amzn2, aapl], join='inner')
# Out:
#         date  adjusted_close      volume symbol
# 0 2018-03-23         1495.56   7843966.0   amzn
# 1 2018-03-26         1555.86   5547618.0   amzn
# 2 2018-03-27         1497.05   6793279.0   amzn
# 0 2018-03-23          164.94  40248954.0   aapl
# 1 2018-03-26          172.77  36272617.0   aapl
# 2 2018-03-27          168.34  38962839.0   aapl

# %%
pd.concat([amzn2, aapl], axis=1)
# Out:
#         date  adjusted_close     volume symbol       date  adjusted_close  \
# 0 2018-03-23         1495.56  7843966.0   amzn 2018-03-23          164.94
# 1 2018-03-26         1555.86  5547618.0   amzn 2018-03-26          172.77
# 2 2018-03-27         1497.05  6793279.0   amzn 2018-03-27          168.34
#
#        volume symbol
# 0  40248954.0   aapl
# 1  36272617.0   aapl
# 2  38962839.0   aapl

# %%
# inner join outer join practice

# %%
df1 = pd.DataFrame(
       {
         "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
         "C": ["C0", "C1", "C2", "C3"],
         "D": ["D0", "D1", "D2", "D3"],
     },
    index=[0, 1, 2, 3],
 )

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame(
      {
          "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
         "C": ["C4", "C5", "C6", "C7"],
         "D": ["D4", "D5", "D6", "D7"],
     },
      index=[4, 5, 6, 7],
 )

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3 = pd.DataFrame(
      {
           "A": ["A8", "A9", "A10", "A11"],
           "B": ["B8", "B9", "B10", "B11"],
         "C": ["C8", "C9", "C10", "C11"],
          "D": ["D8", "D9", "D10", "D11"],
      },
        index=[8, 9, 10, 11],
  )

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
frames = [df1, df2, df3]
result = pd.concat(frames)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
result = pd.concat(frames, keys=["x", "y", "z"])

result
# Out:
#         A    B    C    D
# x 0    A0   B0   C0   D0
#   1    A1   B1   C1   D1
#   2    A2   B2   C2   D2
#   3    A3   B3   C3   D3
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7
# z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
result.loc['y']
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df4 = pd.DataFrame(
     {
          "B": ["B2", "B3", "B6", "B7"],
         "D": ["D2", "D3", "D6", "D7"],
          "F": ["F2", "F3", "F6", "F7"],
        },
        index=[2, 3, 6, 7],
    )

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
result = pd.concat([df1, df4], axis=1) # default outer join
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
result = pd.concat([df1, df4], axis=1, join="inner")

# %%
result
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
result = pd.concat([df1, df4], axis=1).reindex(df1.index)
result
# Out:
#     A   B   C   D    B    D    F
# 0  A0  B0  C0  D0  NaN  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2   B2   D2   F2
# 3  A3  B3  C3  D3   B3   D3   F3

# %%
pd.concat([df1, df4.reindex(df1.index)], axis=1)
# Out:
#     A   B   C   D    B    D    F
# 0  A0  B0  C0  D0  NaN  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2   B2   D2   F2
# 3  A3  B3  C3  D3   B3   D3   F3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#

# %%
left = pd.DataFrame(
     {
        "key": ["K0", "K1", "K2", "K3"],
            "A": ["A0", "A1", "A2", "A3"],
           "B": ["B0", "B1", "B2", "B3"],
       }
    )
   

right = pd.DataFrame(
      {
          "key": ["K0", "K1", "K2", "K3"],
           "C": ["C0", "C1", "C2", "C3"],
         "D": ["D0", "D1", "D2", "D3"],
      }
    )

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
result = pd.merge(left, right, on="key")
result
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#

# %%
import pandas as pd
  
# Creating dataframe a
a = pd.DataFrame()
  
# Creating Dictionary
d = {'id': [1, 2, 10, 12], 
     'val1': ['a', 'b', 'c', 'd']}
  
a = pd.DataFrame(d)
  
# printing the dataframe

# %%
# Creating dataframe b
b = pd.DataFrame()
  
# Creating dictionary
d = {'id': [1, 2, 9, 8],
     'val1': ['p', 'q', 'r', 's']}
b = pd.DataFrame(d)
  
# printing the dataframe

# %%
a
# Out:
#    id val1
# 0   1    a
# 1   2    b
# 2  10    c
# 3  12    d

# %%
b
# Out:
#    id val1
# 0   1    p
# 1   2    q
# 2   9    r
# 3   8    s

# %%
df = pd.merge(a, b, on='id', how='inner')
df
# Out:
#    id val1_x val1_y
# 0   1      a      p
# 1   2      b      q

# %%
a
# Out:
#    id val1
# 0   1    a
# 1   2    b
# 2  10    c
# 3  12    d

# %%
b
# Out:
#    id val1
# 0   1    p
# 1   2    q
# 2   9    r
# 3   8    s

# %%
df = pd.merge(a, b, on='id', how='left')
df
# Out:
#    id val1_x val1_y
# 0   1      a      p
# 1   2      b      q
# 2  10      c    NaN
# 3  12      d    NaN

# %%
a
# Out:
#    id val1
# 0   1    a
# 1   2    b
# 2  10    c
# 3  12    d

# %%
b
# Out:
#    id val1
# 0   1    p
# 1   2    q
# 2   9    r
# 3   8    s

# %%
df = pd.merge(a, b, on='id', how='right')
df
# Out:
#    id val1_x val1_y
# 0   1      a      p
# 1   2      b      q
# 2   9    NaN      r
# 3   8    NaN      s

# %%
a
# Out:
#    id val1
# 0   1    a
# 1   2    b
# 2  10    c
# 3  12    d

# %%
b
# Out:
#    id val1
# 0   1    p
# 1   2    q
# 2   9    r
# 3   8    s

# %%
df = pd.merge(a, b, on='id', how='outer')
df
# Out:
#    id val1_x val1_y
# 0   1      a      p
# 1   2      b      q
# 2  10      c    NaN
# 3  12      d    NaN
# 4   9    NaN      r
# 5   8    NaN      s

# %%
a = pd.DataFrame()
  
# Creating Dictionary
d = {'id': [1, 2, 10, 12],
     'val1': ['a', 'b', 'c', 'd']}
  
a = pd.DataFrame(d)
# Creating dataframe b
b = pd.DataFrame()
  
# Creating dictionary
d = {'id': [1, 2, 9, 8],
     'val1': ['p', 'q', 'r', 's']}
b = pd.DataFrame(d)

# %%
a
# Out:
#    id val1
# 0   1    a
# 1   2    b
# 2  10    c
# 3  12    d

# %%
b
# Out:
#    id val1
# 0   1    p
# 1   2    q
# 2   9    r
# 3   8    s

# %%
df = pd.merge(a, b, left_index=True, right_index=True)
df
# Out:
#    id_x val1_x  id_y val1_y
# 0     1      a     1      p
# 1     2      b     2      q
# 2    10      c     9      r
# 3    12      d     8      s
