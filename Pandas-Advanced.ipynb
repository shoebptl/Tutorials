# %%
import pandas as pd
fortune=pd.read_csv('fortune1000.csv',index_col='Rank')
sector=fortune.groupby('Sector')

# %%
fortune.head(5)
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
sector

# %%
sector.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
len(sector)
# Out:
# 21

# %%
type(sector)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
for name,group in sector:
    
    print(group['Sector'])
# Out:
# Rank
# 24     Aerospace & Defense
# 45     Aerospace & Defense
# 60     Aerospace & Defense
# 88     Aerospace & Defense
# 118    Aerospace & Defense
# 120    Aerospace & Defense
# 209    Aerospace & Defense
# 245    Aerospace & Defense
# 282    Aerospace & Defense
# 378    Aerospace & Defense
# 389    Aerospace & Defense
# 490    Aerospace & Defense
# 560    Aerospace & Defense
# 605    Aerospace & Defense
# 785    Aerospace & Defense
# 788    Aerospace & Defense
# 836    Aerospace & Defense
# 903    Aerospace & Defense
# 958    Aerospace & Defense
# 987    Aerospace & Defense
# Name: Sector, dtype: object
# Rank
# 91     Apparel
# 231    Apparel
# 340    Apparel
# 354    Apparel
# 448    Apparel
# 547    Apparel
# 575    Apparel
# 597    Apparel
# 683    Apparel
# 695    Apparel
# 726    Apparel
# 794    Apparel
# 877    Apparel
# 882    Apparel
# 917    Apparel
# Name: Sector, dtype: object
# Rank
# 144    Business Services
# 186    Business Services
# 199    Business Services
# ...

# %%
fortune.head(5)
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
sector.get_group('Apparel')['Profits'].max()
# Out:
# 3273

# %%
sector.get_group('Apparel')
# Out:
#                    Company Industry             Location  Revenue  Profits  \
# Rank
# 91                    Nike  Apparel        Beaverton, OR    30601     3273
# 231                     VF  Apparel       Greensboro, NC    12377     1232
# 340                    PVH  Apparel         New York, NY     8020      572
# 354           Ralph Lauren  Apparel         New York, NY     7620      702
# 448            Hanesbrands  Apparel    Winston-Salem, NC     5732      429
# 547           Levi Strauss  Apparel    San Francisco, CA     4495      209
# 575                  Coach  Apparel         New York, NY     4192      402
# 597           Under Armour  Apparel        Baltimore, MD     3963      233
# 683           Fossil Group  Apparel       Richardson, TX     3229      221
# 695        Skechers U.S.A.  Apparel  Manhattan Beach, CA     3159      232
# 726               Carter’s  Apparel          Atlanta, GA     3014      238
# ...

# %%
sector.first()
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...

# %%
# Highest employees in each sector

# %%
sector['Employees'].max()
# Out:
# Sector
# Aerospace & Defense              197200
# Apparel                           65300
# Business Services                216500
# Chemicals                         52000
# Energy                            75600
# Engineering & Construction        92000
# Financials                       331000
# Food and Drug Stores             431000
# Food, Beverages & Tobacco        263000
# Health Care                      203500
# Hotels, Resturants & Leisure     505000
# Household Products               110000
# Industrials                      333000
# Materials                         60000
# Media                            185000
# Motor Vehicles & Parts           215000
# Retailing                       2300000
# Technology                       411798
# Telecommunications               281450
# Transportation                   341240
# Wholesalers                       78500
# Name: Employees, dtype: int64
